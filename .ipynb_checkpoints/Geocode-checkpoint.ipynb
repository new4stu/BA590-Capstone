# %%
# import census geocoder (ref: https://pypi.org/project/censusgeocode/)

import censusgeocode as cg

# %%
# returntype keyword use 'locations' or 'geographies'. 
#'Locations' yields structured information about the address, and 'geographies' yields information about the Census geographies

cg.address('176 Birchwood Drive', city ='Fairfield', state='CT', zipcode='06824', returntype='geographies')
# Out:
# [{'matchedAddress': '176 BIRCHWOOD DR, FAIRFIELD, CT, 06824',
#   'coordinates': {'x': -73.24506, 'y': 41.165016},
#   'tigerLine': {'tigerLineId': '3272719', 'side': 'R'},
#   'addressComponents': {'fromAddress': '130',
#    'toAddress': '198',
#    'preQualifier': '',
#    'preDirection': '',
#    'preType': '',
#    'streetName': 'BIRCHWOOD',
#    'suffixType': 'DR',
#    'suffixDirection': '',
#    'suffixQualifier': '',
#    'city': 'FAIRFIELD',
#    'state': 'CT',
#    'zip': '06824'},
#   'geographies': {'2010 Census Blocks': [{'SUFFIX': '',
#      'GEOID': '090010608001002',
#      'CENTLAT': '+41.1652459',
#      'BLOCK': '1002',
#      'AREAWATER': 0,
#      'STATE': '09',
#      'BASENAME': '1002',
#      'OID': 210404121570418,
#      'LSADC': 'BK',
#      'FUNCSTAT': 'S',
#      'INTPTLAT': '+41.1660640',
#      'STGEOMETRY.AREA': 162374.27,
#      'STGEOMETRY.LEN': 1931.7656,
#      'NAME': 'Block 1002',
#      'OBJECTID': 8780027,
#      'TRACT': '060800',
#      'CENTLON': '-073.2459734',
#      'BLKGRP': '1',
#      'AREALAND': 91939,
#      'INTPTLON': '-073.2447080',
#      'MTFCC': 'G5040',
#      'LWBLKTYP': 'L',
#      'COUNTY': '001'}],
#    'States': [{'STATENS': '01779780',
#      'GEOID': '09',
#      'CENTLAT': '+41.5751437',
#      'AREAWATER': 1815626084,
#      'BASENAME': 'Connecticut',
#      'STATE': '09',
#      'STUSAB': 'CT',
#      'OID': 27490331955805,
#      'LSADC': '00',
#      'FUNCSTAT': 'A',
#      'INTPTLAT': '+41.5798637',
#      'DIVISION': '1',
#      'STGEOMETRY.AREA': 25678229500.0,
#      'STGEOMETRY.LEN': 707396.7,
#      'NAME': 'Connecticut',
#      'REGION': '1',
#      'OBJECTID': 11,
#      'CENTLON': '-072.7393081',
#      'AREALAND': 12542488577,
#      'INTPTLON': '-072.7466572',
#      'MTFCC': 'G4000'}],
#    'Counties': [{'GEOID': '09001',
#      'CENTLAT': '+41.2247152',
#      'AREAWATER': 549299062,
#      'BASENAME': 'Fairfield',
#      'STATE': '09',
#      'OID': 27590697754523,
#      'LSADC': '06',
#      'FUNCSTAT': 'N',
#      'INTPTLAT': '+41.2274128',
#      'STGEOMETRY.AREA': 3835824640.0,
#      'STGEOMETRY.LEN': 336208.22,
#      'NAME': 'Fairfield County',
#      'OBJECTID': 2049,
#      'CENTLON': '-073.3712486',
#      'COUNTYCC': 'H4',
#      'COUNTYNS': '00212794',
#      'AREALAND': 1618645892,
#      'INTPTLON': '-073.3670614',
#      'MTFCC': 'G4020',
#      'COUNTY': '001'}],
#    'Census Tracts': [{'GEOID': '09001060800',
#      'CENTLAT': '+41.1591517',
#      'AREAWATER': 0,
#      'BASENAME': '608',
#      'STATE': '09',
#      'OID': 20790698077892,
#      'LSADC': 'CT',
#      'FUNCSTAT': 'S',
#      'INTPTLAT': '+41.1591517',
#      'STGEOMETRY.AREA': 2514346.2,
#      'STGEOMETRY.LEN': 8173.493,
#      'NAME': 'Census Tract 608',
#      'OBJECTID': 71470,
#      'TRACT': '060800',
#      'CENTLON': '-073.2475554',
#      'AREALAND': 1423922,
#      'INTPTLON': '-073.2475554',
#      'MTFCC': 'G5020',
#      'COUNTY': '001'}]}}]
