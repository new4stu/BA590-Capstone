# %%
# Import Census data and Geographies
# List of Geographies and codes: https://jtleider.github.io/censusdata/geographies.html
# switched the ACS5 file to get zip level data

# setup Census JSON feed
from census import Census
from us import states
c = Census("c99084947ed68bfbd3d7359ba2340346f7984e60")

# importing additional libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import sklearn

#  importing the censusdata and pandas modules, and setting some display options in pandas
import pandas as pd
import censusdata
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)

# importing JSON to Pandas translator
import requests
import urllib.parse
from pandas.io.json import json_normalize

# %%
# B09010_001E	Total:	B09010. Receipt of SSI, Public Assistance Income, or Food Stamps/SNAP in the Past 12 Mnths by Hhld Type for Children < 18 in Hhl
#B06010_001E	Total:	B06010. Place of Birth by Individual Income in the United States
#B06010_002E	No income	B06010. Place of Birth by Individual Income in the United States
#B06010_004E	With income:!!$1 to $9,999 or loss	B06010. Place of Birth by Individual Income in the United States
#B06010_005E	With income:!!$10,000 to $14,999	B06010. Place of Birth by Individual Income in the United States
#B06010_006E	With income:!!$15,000 to $24,999	B06010. Place of Birth by Individual Income in the United States
#B06010_007E	With income:!!$25,000 to $34,999	B06010. Place of Birth by Individual Income in the United States
#B06010_008E	With income:!!$35,000 to $49,999	B06010. Place of Birth by Individual Income in the United States
#B06010_009E	With income:!!$50,000 to $64,999	B06010. Place of Birth by Individual Income in the United States
#B06010_010E	With income:!!$65,000 to $74,999	B06010. Place of Birth by Individual Income in the United States
#B06010_011E	With income:!!$75,000 or more	B06010. Place of Birth by Individual Income in the United States
#B06009_001E	Total:	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_002E	Less than high school graduate	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_003E	High school graduate (includes equivalency)	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_004E	Some college or associate's degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_005E	Bachelor's degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_006E	Graduate or professional degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES

c.acs5.zipcode(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), Census.ALL) 

#c.acs1.zipcode(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
 #              'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), Census.ALL)     
    
# def zipcode(mid=None,mtitle=None,year=None):

#censusdata.search('acs5', 2015, 'label', 'SNAP')

#  This is for the State level        c.acs1.state('B09010_001E', Census.ALL)      ,states.CT.fips, Census.ALL)

#c.acs5.state_zipcode(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
 #              'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'),states.AL.fips, Census.ALL)
    
# change to a datafrom using pandas

acs5z = c.acs5.zipcode(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), Census.ALL) 

# create a single dataframe with all of the zip level data
acs5zip = pd.DataFrame(acs5z)
acs5zip
# Out:
#        B06009_001E  B06009_002E  B06009_003E  B06009_004E  B06009_005E  B06009_006E  B06010_001E  B06010_002E  B06010_004E  B06010_005E  B06010_006E  B06010_007E  B06010_008E  B06010_009E  B06010_010E  B06010_011E  B09010_001E zip code tabulation area
# 0            204.0          0.0         41.0        110.0         35.0         18.0        258.0         16.0         29.0          0.0         41.0          0.0         28.0         80.0         13.0         51.0         87.0                    84306
# 1            343.0         61.0         52.0         76.0         71.0         83.0        373.0          0.0         67.0         99.0         94.0         27.0         32.0         16.0          9.0         29.0         62.0                    84775
# ...

# %%
# B09010_001E	Total:	B09010. Receipt of SSI, Public Assistance Income, or Food Stamps/SNAP in the Past 12 Mnths by Hhld Type for Children < 18 in Hhl
#B06010_001E	Total:	B06010. Place of Birth by Individual Income in the United States
#B06010_002E	No income	B06010. Place of Birth by Individual Income in the United States
#B06010_004E	With income:!!$1 to $9,999 or loss	B06010. Place of Birth by Individual Income in the United States
#B06010_005E	With income:!!$10,000 to $14,999	B06010. Place of Birth by Individual Income in the United States
#B06010_006E	With income:!!$15,000 to $24,999	B06010. Place of Birth by Individual Income in the United States
#B06010_007E	With income:!!$25,000 to $34,999	B06010. Place of Birth by Individual Income in the United States
#B06010_008E	With income:!!$35,000 to $49,999	B06010. Place of Birth by Individual Income in the United States
#B06010_009E	With income:!!$50,000 to $64,999	B06010. Place of Birth by Individual Income in the United States
#B06010_010E	With income:!!$65,000 to $74,999	B06010. Place of Birth by Individual Income in the United States
#B06010_011E	With income:!!$75,000 or more	B06010. Place of Birth by Individual Income in the United States
#B06009_001E	Total:	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_002E	Less than high school graduate	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_003E	High school graduate (includes equivalency)	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_004E	Some college or associate's degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_005E	Bachelor's degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_006E	Graduate or professional degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES


c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.AL.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.AK.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.AZ.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.AR.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.CA.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.CO.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.CT.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.DE.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.FL.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.GA.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.HI.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.ID.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.IL.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.IN.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.IA.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.KS.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.KY.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.LA.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.ME.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MD.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MA.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MI.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MN.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MS.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MO.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MT.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NE.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NV.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NH.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NJ.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NM.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NY.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'),states.NC.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.ND.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.OH.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.OK.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.OR.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.PA.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.RI.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.SC.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.SD.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.TN.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.TX.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.UT.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.VT.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.VA.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.WA.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.WV.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.WI.fips, Census.ALL) 
c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.WY.fips, Census.ALL) 


# change to a dataframe using pandas

countyAL = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.AL.fips, Census.ALL) 
countyAK = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.AK.fips, Census.ALL) 
countyAZ = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.AZ.fips, Census.ALL) 
countyAR = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.AR.fips, Census.ALL) 
countyCA = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.CA.fips, Census.ALL) 
countyCO = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.CO.fips, Census.ALL) 
countyCT = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.CT.fips, Census.ALL) 
countyDE = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.DE.fips, Census.ALL) 
countyFL = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.FL.fips, Census.ALL) 
countyGA = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.GA.fips, Census.ALL) 
countyHI = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.HI.fips, Census.ALL) 
countyID = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.ID.fips, Census.ALL) 
countyIL = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.IL.fips, Census.ALL) 
countyIN = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.IN.fips, Census.ALL) 
countyIA = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.IA.fips, Census.ALL) 
countyKS = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.KS.fips, Census.ALL) 
countyKY = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.KY.fips, Census.ALL) 
countyLA = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.LA.fips, Census.ALL) 
countyME = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.ME.fips, Census.ALL) 
countyMD = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MD.fips, Census.ALL) 
countyMA = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MA.fips, Census.ALL) 
countyMI = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MI.fips, Census.ALL) 
countyMN = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MN.fips, Census.ALL) 
countyMS = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MS.fips, Census.ALL) 
countyMO = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MO.fips, Census.ALL) 
countyMT = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.MT.fips, Census.ALL) 
countyNE = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NE.fips, Census.ALL) 
countyNV = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NV.fips, Census.ALL) 
countyNH = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NH.fips, Census.ALL) 
countyNJ = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NJ.fips, Census.ALL) 
countyNM = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NM.fips, Census.ALL) 
countyNY = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.NY.fips, Census.ALL) 
countyNC = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'),states.NC.fips, Census.ALL) 
countyND = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.ND.fips, Census.ALL) 
countyOH = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'),states.OH.fips, Census.ALL) 
countyOK = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.OK.fips, Census.ALL) 
countyOR = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.OR.fips, Census.ALL) 
countyPA = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.PA.fips, Census.ALL) 
countyRI = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.RI.fips, Census.ALL) 
countySC = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.SC.fips, Census.ALL) 
countySD = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.SD.fips, Census.ALL) 
countyTN = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.TN.fips, Census.ALL) 
countyTX = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.TX.fips, Census.ALL) 
countyUT = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.UT.fips, Census.ALL) 
countyVT = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.VT.fips, Census.ALL) 
countyVA = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.VA.fips, Census.ALL) 
countyWA = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.WA.fips, Census.ALL) 
countyWV = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.WV.fips, Census.ALL) 
countyWI = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.WI.fips, Census.ALL) 
countyWY = c.acs5.state_county(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), states.WY.fips, Census.ALL) 



# create a single dataframe with all of the county level data
acs_countydf = pd.DataFrame(countyAL + countyAK + countyAZ +countyAR +countyCA +countyCO +countyCT +countyDE +countyFL +countyGA +countyHI +countyID +countyIL +countyIN +countyIA +countyKS 
                            +countyKY +countyLA +countyME +countyMD +countyMA +countyMI +countyMN +countyMS +countyMO +countyMT +countyNE +countyNV +countyNH +countyNJ +countyNM +countyNY 
                            +countyNC +countyND +countyOH +countyOK +countyOR +countyPA +countyRI +countySC +countySD +countyTN +countyTX +countyUT + countyVT +countyVA + countyWA +countyWV 
                            +countyWI +countyWY)


acs_countydf
# Out:
#       B06009_001E  B06009_002E  B06009_003E  B06009_004E  B06009_005E  B06009_006E  B06010_001E  B06010_002E  B06010_004E  B06010_005E  B06010_006E  B06010_007E  B06010_008E  B06010_009E  B06010_010E  B06010_011E  B09010_001E county state
# 0         14794.0       2513.0       6910.0       3528.0       1079.0        764.0      17655.0       4683.0       3349.0       2055.0       2343.0       1766.0       1417.0        898.0        265.0        879.0       5071.0    099    01
# 1         23370.0       5136.0       9546.0       6308.0       1671.0        709.0      27280.0       4636.0       4966.0       2865.0       3941.0       2662.0       3510.0       2164.0        647.0       1889.0       7242.0    079    01
# 2         92452.0       9303.0      22660.0      28267.0      18261.0      13961.0     128522.0      18558.0      28448.0      11634.0      15831.0      12696.0      15387.0      10654.0       3608.0      11706.0      33809.0    081    01
# ...

# %%
# export to csv combined raw data

acs_countydf.to_csv('./acs5_county.csv')

# %%
# B09010_001E   Total:  B09010. Receipt of SSI, Public Assistance Income, or Food Stamps/SNAP in the Past 12 Mnths by Hhld Type for Children < 18 in Hhl
#B06010_001E    Total:  B06010. Place of Birth by Individual Income in the United States
#B06010_002E    No income   B06010. Place of Birth by Individual Income in the United States
#B06010_004E    With income:!!$1 to $9,999 or loss  B06010. Place of Birth by Individual Income in the United States
#B06010_005E    With income:!!$10,000 to $14,999    B06010. Place of Birth by Individual Income in the United States
#B06010_006E    With income:!!$15,000 to $24,999    B06010. Place of Birth by Individual Income in the United States
#B06010_007E    With income:!!$25,000 to $34,999    B06010. Place of Birth by Individual Income in the United States
#B06010_008E    With income:!!$35,000 to $49,999    B06010. Place of Birth by Individual Income in the United States
#B06010_009E    With income:!!$50,000 to $64,999    B06010. Place of Birth by Individual Income in the United States
#B06010_010E    With income:!!$65,000 to $74,999    B06010. Place of Birth by Individual Income in the United States
#B06010_011E    With income:!!$75,000 or more   B06010. Place of Birth by Individual Income in the United States
#B06009_001E    Total:  B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_002E    Less than high school graduate  B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_003E    High school graduate (includes equivalency) B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_004E    Some college or associate's degree  B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_005E    Bachelor's degree   B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_006E    Graduate or professional degree B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES​


c.acs5.state(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), Census.ALL) 


# change to a dataframe using pandas

states = c.acs5.state(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'), Census.ALL) 

# create a single dataframe with all of the state level data
acs_statesdf = pd.DataFrame(states)


acs_statesdf
# Out:
#     B06009_001E  B06009_002E  B06009_003E  B06009_004E  B06009_005E  B06009_006E  B06010_001E  B06010_002E  B06010_004E  B06010_005E  B06010_006E  B06010_007E  B06010_008E  B06010_009E  B06010_010E  B06010_011E  B09010_001E state
# 0           NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN     7.30e+05    72
# 1      3.28e+06     4.81e+05     1.01e+06     9.79e+05     5.04e+05     3.00e+05     3.94e+06     5.81e+05     7.09e+05     4.02e+05     5.95e+05     4.32e+05     4.51e+05     3.00e+05     1.14e+05     3.57e+05     1.10e+06    01
# 2      4.75e+05     3.62e+04     1.31e+05     1.70e+05     8.83e+04     4.95e+04     5.82e+05     3.02e+04     1.12e+05     4.07e+04     7.31e+04     6.09e+04     7.30e+04     5.80e+04     2.90e+04     1.05e+05     1.86e+05    02
# ...

# %%
# export to csv combined raw data

acs_statesdf.to_csv('./acs5_state.csv')

# %%
# B09010_001E   Total:  B09010. Receipt of SSI, Public Assistance Income, or Food Stamps/SNAP in the Past 12 Mnths by Hhld Type for Children < 18 in Hhl
#B06010_001E    Total:  B06010. Place of Birth by Individual Income in the United States
#B06010_002E    No income   B06010. Place of Birth by Individual Income in the United States
#B06010_004E    With income:!!$1 to $9,999 or loss  B06010. Place of Birth by Individual Income in the United States
#B06010_005E    With income:!!$10,000 to $14,999    B06010. Place of Birth by Individual Income in the United States
#B06010_006E    With income:!!$15,000 to $24,999    B06010. Place of Birth by Individual Income in the United States
#B06010_007E    With income:!!$25,000 to $34,999    B06010. Place of Birth by Individual Income in the United States
#B06010_008E    With income:!!$35,000 to $49,999    B06010. Place of Birth by Individual Income in the United States
#B06010_009E    With income:!!$50,000 to $64,999    B06010. Place of Birth by Individual Income in the United States
#B06010_010E    With income:!!$65,000 to $74,999    B06010. Place of Birth by Individual Income in the United States
#B06010_011E    With income:!!$75,000 or more   B06010. Place of Birth by Individual Income in the United States
#B06009_001E    Total:  B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_002E    Less than high school graduate  B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_003E    High school graduate (includes equivalency) B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_004E    Some college or associate's degree  B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_005E    Bachelor's degree   B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_006E    Graduate or professional degree B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES​


c.acs5.us(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'))


# change to a dataframe using pandas

acsus = c.acs5.us(('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
                  'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'))

# create a single dataframe with all of the state level data
acs_usdf = pd.DataFrame(acsus)


acs_usdf
# Out:
#    B06009_001E  B06009_002E  B06009_003E  B06009_004E  B06009_005E  B06009_006E  B06010_001E  B06010_002E  B06010_004E  B06010_005E  B06010_006E  B06010_007E  B06010_008E  B06010_009E  B06010_010E  B06010_011E  B09010_001E us
# 0     2.16e+08     2.74e+07     5.91e+07     6.29e+07     4.14e+07     2.55e+07     2.60e+08     3.56e+07     4.18e+07     2.26e+07     3.60e+07     2.85e+07     3.10e+07     2.18e+07     9.19e+06     3.35e+07     7.34e+07  1

# %%
# export to csv combined raw data

acs_usdf.to_csv('./acs5_us.csv')
