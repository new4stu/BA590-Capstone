# %%
# import the censusdata and pandas modules and set some display options in pandas for nicer output:

import pandas as pd
import censusdata
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)

from pandas.io.json import json_normalize

# %%
# ACS5 labels of interest
# Most recent data is 2017

# B09010_001E	Total:	B09010. Receipt of SSI, Public Assistance Income, or Food Stamps/SNAP in the Past 12 Mnths by Hhld Type for Children < 18 in Hhl
#B06010_001E	Total:	B06010. Place of Birth by Individual Income in the United States
#B06010_002E	No income	B06010. Place of Birth by Individual Income in the United States
#B06010_004E	With income:!!$1 to $9,999 or loss	B06010. Place of Birth by Individual Income in the United States
#B06010_005E	With income:!!$10,000 to $14,999	B06010. Place of Birth by Individual Income in the United States
#B06010_006E	With income:!!$15,000 to $24,999	B06010. Place of Birth by Individual Income in the United States
#B06010_007E	With income:!!$25,000 to $34,999	B06010. Place of Birth by Individual Income in the United States
#B06010_008E	With income:!!$35,000 to $49,999	B06010. Place of Birth by Individual Income in the United States
#B06010_009E	With income:!!$50,000 to $64,999	B06010. Place of Birth by Individual Income in the United States
#B06010_010E	With income:!!$65,000 to $74,999	B06010. Place of Birth by Individual Income in the United States
#B06010_011E	With income:!!$75,000 or more	B06010. Place of Birth by Individual Income in the United States
#B06009_001E	Total:	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_002E	Less than high school graduate	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_003E	High school graduate (includes equivalency)	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_004E	Some college or associate's degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_005E	Bachelor's degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES
#B06009_006E	Graduate or professional degree	B06009. PLACE OF BIRTH BY EDUCATIONAL ATTAINMENT IN THE UNITED STATES

#SF1 labels of interest
# Count of Single Race Households by Zip
    #P003001 Total poulation
    #P003002 Population of one race
    #P003003 White alone
    #P003004 Black or African American alone
    #P003005 American Indian and Alaska Native alone
    #P003006 Asian alone
    #P003007 Native Hawaiian and Other Pacific Islander alone
    #P003008 Some other race alone
    #P004002 Hispanic or Latino
    #P013001 Both sexes MEDIAN AGE BY SEX
    #P013002 Male MEDIAN AGE BY SEX
    #P013003 Female MEDIAN AGE BY SEX
    #P015001 Total HOUSEHOLDS
    #P017001 Average household size 
    #P031001 Total FAMILIES


#censusdata.printtable(censusdata.censustable('acs5', 2017, {'B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
 #              'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'}))

#countyacs5 = censusdata.download('acs5', 2017, censusdata.censusgeo([('state', '*'), ('county', '*')]),
stateacs5 = censusdata.download('acs5', 2017, censusdata.censusgeo([('state', '*')]),                                 
                                   ['B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 
                                     'B06010_009E', 'B06010_010E', 'B06010_011E', 'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'])
                                                             

#county = censusdata.download('acs5', 'sf1', 2017, 2010, censusdata.censusgeo([('county', '*')]),
 #                                  ['B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 
  #                                  'B06010_009E', 'B06010_010E', 'B06010_011E', 'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E'
   #                                 'P003001','P003002', 'P003003','P003004', 'P003005', 'P003006', 'P003007','P003008', 'P004002', 'P013001', 'P013002', 'P013003', 
    #                                'P015001', 'P017001', 'P031001'])            
    
#countysf1 = censusdata.download('sf1', 2010, censusdata.censusgeo([('state', '*'), ('county', '*')]), 
statesf1 = censusdata.download('sf1', 2010, censusdata.censusgeo([('state', '*')]),                                
                                    ['P003001','P003002', 'P003003','P003004', 'P003005', 'P003006', 'P003007','P003008', 'P004002', 'P013001', 'P013002', 'P013003', 
                                    'P015001', 'P017001', 'P031001']) 

state = stateacs5.append(statesf1, 'sort=True')

#state = stateacs5.pd.concat(statesf1, 'sort=True')

state.describe()


# ('B09010_001E', 'B06010_001E', 'B06010_002E', 'B06010_004E', 'B06010_005E', 'B06010_006E', 'B06010_007E','B06010_008E', 'B06010_009E', 'B06010_010E', 'B06010_011E',
#               'B06009_001E', 'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E', 'B06009_006E')
# Out:
#        B06009_001E  B06009_002E  B06009_003E  B06009_004E  B06009_005E  B06009_006E  B06010_001E  B06010_002E  B06010_004E  B06010_005E    ...       P003006   P003007   P003008   P004002  P013001  P013002  P013003   P015001  P017001   P031001
# count     5.10e+01     5.10e+01     5.10e+01     5.10e+01     5.10e+01     5.10e+01     5.10e+01     5.10e+01     5.10e+01     5.10e+01    ...         52.00  5.20e+01  5.20e+01  5.20e+01    52.00    52.00    52.00  5.20e+01    52.00  5.20e+01
# mean      4.24e+06     5.38e+05     1.16e+06     1.23e+06     8.11e+05     5.00e+05     5.10e+06     6.97e+05     8.20e+05     4.44e+05    ...      10391.98  3.73e+05  1.76e+05  4.97e+06    37.49    36.26    38.67  2.27e+06     2.52  1.44e+06
# std       4.80e+06     7.84e+05     1.18e+06     1.38e+06     9.53e+05     5.88e+05     5.79e+06     9.54e+05     8.88e+05     5.14e+05    ...      27154.44  9.42e+05  2.71e+05  4.79e+06     2.29     2.16     2.43  2.41e+06     0.16  1.67e+06
# ...

# %%
print(state).head(15)
# Out:
#      B06009_001E  B06009_002E  B06009_003E  B06009_004E  B06009_005E  B06009_006E  B06010_001E  B06010_002E  B06010_004E  B06010_005E    ...     P003006   P003007   P003008   P004002  P013001  P013002  P013003   P015001  P017001   P031001
# 0            NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN          NaN    ...         NaN       NaN       NaN       NaN      NaN      NaN      NaN       NaN      NaN       NaN
# 1       3.28e+06     4.81e+05     1.01e+06     9.79e+05     5.04e+05     3.00e+05     3.94e+06     5.81e+05     7.09e+05     4.02e+05    ...         NaN       NaN       NaN       NaN      NaN      NaN      NaN       NaN      NaN       NaN
# 2       4.75e+05     3.62e+04     1.31e+05     1.70e+05     8.83e+04     4.95e+04     5.82e+05     3.02e+04     1.12e+05     4.07e+04    ...         NaN       NaN       NaN       NaN      NaN      NaN      NaN       NaN      NaN       NaN
# ...

# %%
# create csv file

state.to_csv('census-state.csv')
state = csv.write("census-state.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7f8e97567f9c> in <module>
#       1 # create csv file
#       2
# ----> 3 df.to_csv('census-state.csv')
#       4 state = csv.write("census-state.csv")
#
# NameError: name 'df' is not defined
