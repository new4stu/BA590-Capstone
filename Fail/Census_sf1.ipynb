# %%
# Import Census data and Geographies
# List of Geographies and codes: https://jtleider.github.io/censusdata/geographies.html

from census import Census
from us import states

c = Census("c99084947ed68bfbd3d7359ba2340346f7984e60", year=2010)
c.sf1.tables()
#c.acs5.get(('NAME', 'B25034_010E'),
#          {'for': 'state:{}'.format(states.MD.fips)})
# Out:
# [{'name': 'P12I',
#   'description': 'SEX BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'variables': 'https://api.census.gov/data/2010/dec/sf1/groups/P12I.json'},
#  {'name': 'P12C',
#   'description': 'SEX BY AGE (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/dec/sf1/groups/P12C.json'},
#  {'name': 'P12D',
#   'description': 'SEX BY AGE (ASIAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/dec/sf1/groups/P12D.json'},
#  {'name': 'P12A',
#   'description': 'SEX BY AGE (WHITE ALONE)',
#   'variables': 'https://api.census.gov/data/2010/dec/sf1/groups/P12A.json'},
#  {'name': 'P12B',
#   'description': 'SEX BY AGE (BLACK OR AFRICAN AMERICAN ALONE)',
#   'variables': 'https://api.census.gov/data/2010/dec/sf1/groups/P12B.json'},
#  {'name': 'P12G',
#   'description': 'SEX BY AGE (TWO OR MORE RACES)',
#   'variables': 'https://api.census.gov/data/2010/dec/sf1/groups/P12G.json'},
#  {'name': 'P12H',
# ...

# %%
c.sf1.state_zipcode(('NAME', 'H006002'),states.CT.fips,'06824')

#c.sf1.state('P36I', Census.ALL, )
# c.sf1.state_county_tract('NAME', states.AK.fips, '170', Census.ALL)
# Out:
# [{'NAME': 'ZCTA5 06824, Connecticut',
#   'H006002': 10906.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06824'}]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-fb16bd27d0c8> in <module>()
# ----> 1 c.head()
#
# AttributeError: 'Census' object has no attribute 'head'

# %%
c.sf1.state_county_tract('NAME', states.AK.fips, '170', Census.ALL)
# Out:
# [{'NAME': 'Census Tract 1.01, Matanuska-Susitna Borough, Alaska',
#   'state': '02',
#   'county': '170',
#   'tract': '000101'},
#  {'NAME': 'Census Tract 1.02, Matanuska-Susitna Borough, Alaska',
#   'state': '02',
#   'county': '170',
#   'tract': '000102'},
#  {'NAME': 'Census Tract 2, Matanuska-Susitna Borough, Alaska',
#   'state': '02',
#   'county': '170',
#   'tract': '000200'},
#  {'NAME': 'Census Tract 3, Matanuska-Susitna Borough, Alaska',
#   'state': '02',
#   'county': '170',
#   'tract': '000300'},
#  {'NAME': 'Census Tract 4.01, Matanuska-Susitna Borough, Alaska',
#   'state': '02',
#   'county': '170',
#   'tract': '000401'},
#  {'NAME': 'Census Tract 4.02, Matanuska-Susitna Borough, Alaska',
#   'state': '02',
#   'county': '170',
#   'tract': '000402'},
#  {'NAME': 'Census Tract 5.01, Matanuska-Susitna Borough, Alaska',
#   'state': '02',
#   'county': '170',
#   'tract': '000501'},
#  {'NAME': 'Census Tract 5.02, Matanuska-Susitna Borough, Alaska',
# ...

# %%
# importing proper libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import sklearn

# %%
#  importing the censusdata and pandas modules, and setting some display options in pandas

import pandas as pd
import censusdata
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-82821a6283e4> in <module>()
#       2
#       3 import pandas as pd
# ----> 4 import censusdata
#       5 pd.set_option('display.expand_frame_repr', False)
#       6 pd.set_option('display.precision', 2)
#
# ModuleNotFoundError: No module named 'censusdata'

# %%
# Download data from Census API
# https://jtleider.github.io/censusdata/api.html#module-censusdata.download
censusdata.download.download(src, year, geo, var, key=None, tabletype='detail', endpt='')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4f67dfd87ae1> in <module>()
#       1 # Download data from Census API
#       2 # https://jtleider.github.io/censusdata/api.html#module-censusdata.download
# ----> 3 censusdata.download.download(src, year, geo, var, key=None, tabletype='detail', endpt='')
#
# NameError: name 'censusdata' is not defined

# %%
# Access USDA stats from the National Agricultural Statistics Service (NASS)
with open('5B9610D0-2DBF-389B-BA0C-38CA734388B6') as f:
    usda_key = f.read().rstrip()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-6ee3624eda9c> in <module>()
#       1 # Access USDA stats from the National Agricultural Statistics Service (VASS)
# ----> 2 with open('5B9610D0-2DBF-389B-BA0C-38CA734388B6') as f:
#       3     usda_key = f.read().rstrip()
#
# FileNotFoundError: [Errno 2] No such file or directory: '5B9610D0-2DBF-389B-BA0C-38CA734388B6'

# %%
from nass import NassApi
api = NassApi('5B9610D0-2DBF-389B-BA0C-38CA734388B6')

q = api.query()
q.count()
# Out:
# 35092956
