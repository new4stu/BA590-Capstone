# %%
# Import Census data and Geographies
# List of Geographies and codes: https://jtleider.github.io/censusdata/geographies.html

from census import Census
from us import states

# importing additional libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import sklearn

#  importing the censusdata and pandas modules, and setting some display options in pandas

import pandas as pd
import censusdata
pd.set_option('display.expand_frame_repr', False)
pd.set_option('display.precision', 2)

c = Census("c99084947ed68bfbd3d7359ba2340346f7984e60")
c.sf1.tables()
# Count of Single Race Households by Zip
    #P003001 Total poulation
    #P003002 Population of one race
    #P003003 White alone
    #P003004 Black or African American alone
    #P003005 American Indian and Alaska Native alone
    #P003006 Asian alone
    #P003007 Native Hawaiian and Other Pacific Islander alone
    #P003008 Some other race alone
    #P004002 Hispanic or Latino
    #P013001 Both sexes MEDIAN AGE BY SEX
    #P013002 Male MEDIAN AGE BY SEX
    #P013003 Female MEDIAN AGE BY SEX
    #P015001 Total HOUSEHOLDS
    #P017001 Average household size 
    #P031001 Total FAMILIES
    
# ZIP Code Tabulation Area (ZCTA)

States1 = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'
, 'ZZ']

for s in States1:
    if s == 'ZZ':
        break
    else:
        print(s)
        argString1="states."+s+".fips"
        print (argString1)
        c.sf1.state_zipcode(('NAME', 'P003001','P003002', 'P003003','P003004', 'P003005', 'P003006', 'P003007','P003008', 'P004002', 'P013001', 'P013002', 'P013003', 'P015001','P017001', 'P031001'),states.AL.fips, Census.ALL)
        #c.sf1.state_zipcode(('NAME', 'P003001','P003002', 'P003003','P003004', 'P003005', 'P003006', 'P003007','P003008', 'P004002', 'P013001', 'P013002', 'P013003', 'P015001','P017001', 'P031001'),argString1, Census.ALL)
        


c.sf1.state_zipcode(('NAME', 'P003001','P003002', 'P003003','P003004', 'P003005', 'P003006', 'P003007','P003008', 'P004002', 'P013001', 'P013002', 'P013003', 'P015001','P017001', 'P031001'),states.CT.fips, Census.ALL)
# Out:
# AL
# states.AL.fips
# AK
# states.AK.fips
# AZ
# states.AZ.fips
# AR
# states.AR.fips
# CA
# states.CA.fips
# CO
# states.CO.fips
# CT
# states.CT.fips
# DE
# states.DE.fips
# FL
# states.FL.fips
# GA
# states.GA.fips
# HI
# states.HI.fips
# ID
# states.ID.fips
# IL
# states.IL.fips
# IN
# states.IN.fips
# IA
# states.IA.fips
# KS
# states.KS.fips
# KY
# states.KY.fips
# LA
# states.LA.fips
# ME
# states.ME.fips
# MD
# states.MD.fips
# MA
# states.MA.fips
# MI
# states.MI.fips
# MN
# states.MN.fips
# MS
# states.MS.fips
# MO
# states.MO.fips
# MT
# states.MT.fips
# NE
# states.NE.fips
# NV
# states.NV.fips
# NH
# states.NH.fips
# NJ
# states.NJ.fips
# NM
# states.NM.fips
# NY
# states.NY.fips
# NC
# states.NC.fips
# ND
# states.ND.fips
# OH
# states.OH.fips
# OK
# states.OK.fips
# OR
# states.OR.fips
# PA
# states.PA.fips
# RI
# states.RI.fips
# SC
# states.SC.fips
# SD
# states.SD.fips
# TN
# states.TN.fips
# TX
# states.TX.fips
# UT
# states.UT.fips
# VT
# states.VT.fips
# VA
# states.VA.fips
# WA
# states.WA.fips
# WV
# states.WV.fips
# WI
# states.WI.fips
# WY
# states.WY.fips
# [{'NAME': 'ZCTA5 06001, Connecticut',
#   'P003001': 18385.0,
#   'P003002': 16510.0,
#   'P003003': 276.0,
#   'P003004': 16.0,
#   'P003005': 1156.0,
#   'P003006': 1.0,
#   'P003007': 105.0,
#   'P003008': 321.0,
#   'P004002': 17767.0,
#   'P013001': 45.0,
#   'P013002': 43.8,
#   'P013003': 46.0,
#   'P015001': 7197.0,
#   'P017001': 2.51,
#   'P031001': 4801.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06001'},
#  {'NAME': 'ZCTA5 06002, Connecticut',
#   'P003001': 20486.0,
#   'P003002': 7304.0,
#   'P003003': 11781.0,
#   'P003004': 52.0,
#   'P003005': 385.0,
#   'P003006': 8.0,
#   'P003007': 342.0,
#   'P003008': 614.0,
#   'P004002': 19337.0,
#   'P013001': 47.9,
#   'P013002': 44.7,
#   'P013003': 50.3,
#   'P015001': 8554.0,
#   'P017001': 2.32,
#   'P031001': 3656.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06002'},
#  {'NAME': 'ZCTA5 06010, Connecticut',
#   'P003001': 60448.0,
#   'P003002': 53037.0,
#   'P003003': 2323.0,
#   'P003004': 117.0,
#   'P003005': 1173.0,
#   'P003006': 10.0,
#   'P003007': 2252.0,
#   'P003008': 1536.0,
#   'P004002': 54619.0,
#   'P013001': 40.3,
#   'P013002': 38.8,
#   'P013003': 41.8,
#   'P015001': 25305.0,
#   'P017001': 2.36,
#   'P031001': 12959.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06010'},
#  {'NAME': 'ZCTA5 06013, Connecticut',
#   'P003001': 9326.0,
#   'P003002': 8998.0,
#   'P003003': 60.0,
#   'P003004': 1.0,
#   'P003005': 138.0,
#   'P003006': 3.0,
#   'P003007': 42.0,
#   'P003008': 84.0,
#   'P004002': 9080.0,
#   'P013001': 42.5,
#   'P013002': 41.8,
#   'P013003': 43.2,
#   'P015001': 3303.0,
#   'P017001': 2.82,
#   'P031001': 2534.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06013'},
#  {'NAME': 'ZCTA5 06016, Connecticut',
#   'P003001': 6226.0,
#   'P003002': 5303.0,
#   'P003003': 482.0,
#   'P003004': 12.0,
#   'P003005': 115.0,
#   'P003006': 5.0,
#   'P003007': 186.0,
#   'P003008': 123.0,
#   'P004002': 5821.0,
#   'P013001': 41.1,
#   'P013002': 40.4,
#   'P013003': 41.8,
#   'P015001': 2544.0,
#   'P017001': 2.44,
#   'P031001': 1405.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06016'},
#  {'NAME': 'ZCTA5 06018, Connecticut',
#   'P003001': 2865.0,
#   'P003002': 2753.0,
#   'P003003': 37.0,
#   'P003004': 3.0,
#   'P003005': 9.0,
#   'P003006': 0.0,
#   'P003007': 36.0,
#   'P003008': 27.0,
#   'P004002': 2688.0,
#   'P013001': 45.7,
#   'P013002': 43.1,
#   'P013003': 47.9,
#   'P015001': 1275.0,
#   'P017001': 2.16,
#   'P031001': 555.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06018'},
#  {'NAME': 'ZCTA5 06019, Connecticut',
#   'P003001': 10129.0,
#   'P003002': 9690.0,
#   'P003003': 94.0,
#   'P003004': 26.0,
#   'P003005': 153.0,
#   'P003006': 2.0,
#   'P003007': 45.0,
#   'P003008': 119.0,
#   'P004002': 9866.0,
#   'P013001': 43.9,
#   'P013002': 43.1,
#   'P013003': 44.6,
#   'P015001': 4086.0,
#   'P017001': 2.46,
#   'P031001': 2443.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06019'},
#  {'NAME': 'ZCTA5 06020, Connecticut',
#   'P003001': 0.0,
#   'P003002': 0.0,
#   'P003003': 0.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 0.0,
#   'P004002': 0.0,
#   'P013001': 0.0,
#   'P013002': 0.0,
#   'P013003': 0.0,
#   'P015001': 0.0,
#   'P017001': 0.0,
#   'P031001': 0.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06020'},
#  {'NAME': 'ZCTA5 06021, Connecticut',
#   'P003001': 314.0,
#   'P003002': 305.0,
#   'P003003': 1.0,
#   'P003004': 2.0,
#   'P003005': 3.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 3.0,
#   'P004002': 307.0,
#   'P013001': 44.5,
#   'P013002': 45.8,
#   'P013003': 42.8,
#   'P015001': 118.0,
#   'P017001': 2.53,
#   'P031001': 67.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06021'},
#  {'NAME': 'ZCTA5 06022, Connecticut',
#   'P003001': 163.0,
#   'P003002': 161.0,
#   'P003003': 0.0,
#   'P003004': 0.0,
#   'P003005': 2.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 0.0,
#   'P004002': 161.0,
#   'P013001': 46.7,
#   'P013002': 47.5,
#   'P013003': 46.6,
#   'P015001': 64.0,
#   'P017001': 2.55,
#   'P031001': 40.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06022'},
#  {'NAME': 'ZCTA5 06023, Connecticut',
#   'P003001': 1296.0,
#   'P003002': 1256.0,
#   'P003003': 0.0,
#   'P003004': 2.0,
#   'P003005': 24.0,
#   'P003006': 0.0,
#   'P003007': 1.0,
#   'P003008': 13.0,
#   'P004002': 1267.0,
#   'P013001': 45.2,
#   'P013002': 43.2,
#   'P013003': 46.4,
#   'P015001': 503.0,
#   'P017001': 2.57,
#   'P031001': 297.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06023'},
#  {'NAME': 'ZCTA5 06024, Connecticut',
#   'P003001': 647.0,
#   'P003002': 638.0,
#   'P003003': 3.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 4.0,
#   'P003008': 2.0,
#   'P004002': 627.0,
#   'P013001': 41.5,
#   'P013002': 41.7,
#   'P013003': 41.4,
#   'P015001': 255.0,
#   'P017001': 2.49,
#   'P031001': 149.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06024'},
#  {'NAME': 'ZCTA5 06026, Connecticut',
#   'P003001': 5117.0,
#   'P003002': 4689.0,
#   'P003003': 108.0,
#   'P003004': 8.0,
#   'P003005': 132.0,
#   'P003006': 4.0,
#   'P003007': 57.0,
#   'P003008': 119.0,
#   'P004002': 4946.0,
#   'P013001': 42.6,
#   'P013002': 41.8,
#   'P013003': 43.3,
#   'P015001': 2049.0,
#   'P017001': 2.5,
#   'P031001': 1264.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06026'},
#  {'NAME': 'ZCTA5 06027, Connecticut',
#   'P003001': 1492.0,
#   'P003002': 1448.0,
#   'P003003': 5.0,
#   'P003004': 6.0,
#   'P003005': 13.0,
#   'P003006': 0.0,
#   'P003007': 4.0,
#   'P003008': 16.0,
#   'P004002': 1485.0,
#   'P013001': 45.6,
#   'P013002': 43.9,
#   'P013003': 46.9,
#   'P015001': 551.0,
#   'P017001': 2.69,
#   'P031001': 332.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06027'},
#  {'NAME': 'ZCTA5 06029, Connecticut',
#   'P003001': 15547.0,
#   'P003002': 14321.0,
#   'P003003': 300.0,
#   'P003004': 29.0,
#   'P003005': 514.0,
#   'P003006': 3.0,
#   'P003007': 110.0,
#   'P003008': 270.0,
#   'P004002': 15149.0,
#   'P013001': 41.0,
#   'P013002': 40.6,
#   'P013003': 41.3,
#   'P015001': 6236.0,
#   'P017001': 2.49,
#   'P031001': 3731.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06029'},
#  {'NAME': 'ZCTA5 06031, Connecticut',
#   'P003001': 1287.0,
#   'P003002': 1250.0,
#   'P003003': 9.0,
#   'P003004': 1.0,
#   'P003005': 3.0,
#   'P003006': 1.0,
#   'P003007': 3.0,
#   'P003008': 20.0,
#   'P004002': 1265.0,
#   'P013001': 47.1,
#   'P013002': 46.8,
#   'P013003': 47.4,
#   'P015001': 562.0,
#   'P017001': 2.29,
#   'P031001': 259.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06031'},
#  {'NAME': 'ZCTA5 06032, Connecticut',
#   'P003001': 17675.0,
#   'P003002': 15133.0,
#   'P003003': 454.0,
#   'P003004': 16.0,
#   'P003005': 1598.0,
#   'P003006': 5.0,
#   'P003007': 139.0,
#   'P003008': 330.0,
#   'P004002': 16999.0,
#   'P013001': 44.8,
#   'P013002': 43.1,
#   'P013003': 46.1,
#   'P015001': 7434.0,
#   'P017001': 2.35,
#   'P031001': 3748.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06032'},
#  {'NAME': 'ZCTA5 06033, Connecticut',
#   'P003001': 28762.0,
#   'P003002': 25215.0,
#   'P003003': 631.0,
#   'P003004': 58.0,
#   'P003005': 2063.0,
#   'P003006': 0.0,
#   'P003007': 321.0,
#   'P003008': 474.0,
#   'P004002': 27463.0,
#   'P013001': 42.9,
#   'P013002': 42.0,
#   'P013003': 43.7,
#   'P015001': 11092.0,
#   'P017001': 2.56,
#   'P031001': 7459.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06033'},
#  {'NAME': 'ZCTA5 06035, Connecticut',
#   'P003001': 7513.0,
#   'P003002': 7243.0,
#   'P003003': 69.0,
#   'P003004': 12.0,
#   'P003005': 76.0,
#   'P003006': 6.0,
#   'P003007': 22.0,
#   'P003008': 85.0,
#   'P004002': 7372.0,
#   'P013001': 45.1,
#   'P013002': 44.4,
#   'P013003': 45.9,
#   'P015001': 2901.0,
#   'P017001': 2.55,
#   'P031001': 1846.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06035'},
#  {'NAME': 'ZCTA5 06037, Connecticut',
#   'P003001': 18565.0,
#   'P003002': 17602.0,
#   'P003003': 138.0,
#   'P003004': 23.0,
#   'P003005': 506.0,
#   'P003006': 2.0,
#   'P003007': 110.0,
#   'P003008': 184.0,
#   'P004002': 17949.0,
#   'P013001': 45.5,
#   'P013002': 44.4,
#   'P013003': 46.7,
#   'P015001': 7303.0,
#   'P017001': 2.53,
#   'P031001': 3957.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06037'},
#  {'NAME': 'ZCTA5 06039, Connecticut',
#   'P003001': 1942.0,
#   'P003002': 1835.0,
#   'P003003': 36.0,
#   'P003004': 3.0,
#   'P003005': 23.0,
#   'P003006': 0.0,
#   'P003007': 11.0,
#   'P003008': 34.0,
#   'P004002': 1883.0,
#   'P013001': 49.9,
#   'P013002': 49.9,
#   'P013003': 50.0,
#   'P015001': 894.0,
#   'P017001': 2.16,
#   'P031001': 375.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06039'},
#  {'NAME': 'ZCTA5 06040, Connecticut',
#   'P003001': 35306.0,
#   'P003002': 25151.0,
#   'P003003': 4820.0,
#   'P003004': 133.0,
#   'P003005': 2013.0,
#   'P003006': 10.0,
#   'P003007': 1908.0,
#   'P003008': 1271.0,
#   'P004002': 30476.0,
#   'P013001': 37.7,
#   'P013002': 36.3,
#   'P013003': 39.0,
#   'P015001': 14587.0,
#   'P017001': 2.38,
#   'P031001': 7828.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06040'},
#  {'NAME': 'ZCTA5 06042, Connecticut',
#   'P003001': 22942.0,
#   'P003002': 16439.0,
#   'P003003': 2332.0,
#   'P003004': 50.0,
#   'P003005': 2614.0,
#   'P003006': 11.0,
#   'P003007': 765.0,
#   'P003008': 731.0,
#   'P004002': 20781.0,
#   'P013001': 35.9,
#   'P013002': 34.1,
#   'P013003': 38.1,
#   'P015001': 10105.0,
#   'P017001': 2.25,
#   'P031001': 4425.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06042'},
#  {'NAME': 'ZCTA5 06043, Connecticut',
#   'P003001': 4986.0,
#   'P003002': 4770.0,
#   'P003003': 53.0,
#   'P003004': 6.0,
#   'P003005': 70.0,
#   'P003006': 0.0,
#   'P003007': 12.0,
#   'P003008': 75.0,
#   'P004002': 4835.0,
#   'P013001': 45.4,
#   'P013002': 45.1,
#   'P013003': 45.7,
#   'P015001': 1918.0,
#   'P017001': 2.6,
#   'P031001': 1137.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06043'},
#  {'NAME': 'ZCTA5 06051, Connecticut',
#   'P003001': 30519.0,
#   'P003002': 16811.0,
#   'P003003': 4898.0,
#   'P003004': 176.0,
#   'P003005': 353.0,
#   'P003006': 9.0,
#   'P003007': 6709.0,
#   'P003008': 1563.0,
#   'P004002': 15421.0,
#   'P013001': 31.2,
#   'P013002': 30.1,
#   'P013003': 32.2,
#   'P015001': 11753.0,
#   'P017001': 2.56,
#   'P031001': 8468.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06051'},
#  {'NAME': 'ZCTA5 06052, Connecticut',
#   'P003001': 7858.0,
#   'P003002': 5679.0,
#   'P003003': 895.0,
#   'P003004': 16.0,
#   'P003005': 95.0,
#   'P003006': 2.0,
#   'P003007': 871.0,
#   'P003008': 300.0,
#   'P004002': 5879.0,
#   'P013001': 39.0,
#   'P013002': 38.0,
#   'P013003': 40.3,
#   'P015001': 3192.0,
#   'P017001': 2.45,
#   'P031001': 1703.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06052'},
#  {'NAME': 'ZCTA5 06053, Connecticut',
#   'P003001': 34863.0,
#   'P003002': 24117.0,
#   'P003003': 3737.0,
#   'P003004': 79.0,
#   'P003005': 1281.0,
#   'P003006': 16.0,
#   'P003007': 4403.0,
#   'P003008': 1230.0,
#   'P004002': 25003.0,
#   'P013001': 32.7,
#   'P013002': 31.4,
#   'P013003': 34.2,
#   'P015001': 13226.0,
#   'P017001': 2.43,
#   'P031001': 6894.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06053'},
#  {'NAME': 'ZCTA5 06057, Connecticut',
#   'P003001': 6707.0,
#   'P003002': 6525.0,
#   'P003003': 21.0,
#   'P003004': 4.0,
#   'P003005': 76.0,
#   'P003006': 0.0,
#   'P003007': 18.0,
#   'P003008': 63.0,
#   'P004002': 6593.0,
#   'P013001': 44.2,
#   'P013002': 44.0,
#   'P013003': 44.4,
#   'P015001': 2504.0,
#   'P017001': 2.67,
#   'P031001': 1582.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06057'},
#  {'NAME': 'ZCTA5 06058, Connecticut',
#   'P003001': 1787.0,
#   'P003002': 1734.0,
#   'P003003': 12.0,
#   'P003004': 2.0,
#   'P003005': 11.0,
#   'P003006': 0.0,
#   'P003007': 7.0,
#   'P003008': 21.0,
#   'P004002': 1754.0,
#   'P013001': 47.5,
#   'P013002': 47.2,
#   'P013003': 47.9,
#   'P015001': 753.0,
#   'P017001': 2.37,
#   'P031001': 378.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06058'},
#  {'NAME': 'ZCTA5 06059, Connecticut',
#   'P003001': 0.0,
#   'P003002': 0.0,
#   'P003003': 0.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 0.0,
#   'P004002': 0.0,
#   'P013001': 0.0,
#   'P013002': 0.0,
#   'P013003': 0.0,
#   'P015001': 0.0,
#   'P017001': 0.0,
#   'P031001': 0.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06059'},
#  {'NAME': 'ZCTA5 06060, Connecticut',
#   'P003001': 2581.0,
#   'P003002': 2465.0,
#   'P003003': 42.0,
#   'P003004': 2.0,
#   'P003005': 21.0,
#   'P003006': 0.0,
#   'P003007': 11.0,
#   'P003008': 40.0,
#   'P004002': 2537.0,
#   'P013001': 43.0,
#   'P013002': 43.0,
#   'P013003': 42.9,
#   'P015001': 874.0,
#   'P017001': 2.95,
#   'P031001': 750.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06060'},
#  {'NAME': 'ZCTA5 06061, Connecticut',
#   'P003001': 169.0,
#   'P003002': 160.0,
#   'P003003': 2.0,
#   'P003004': 0.0,
#   'P003005': 3.0,
#   'P003006': 0.0,
#   'P003007': 2.0,
#   'P003008': 2.0,
#   'P004002': 160.0,
#   'P013001': 44.8,
#   'P013002': 42.5,
#   'P013003': 45.8,
#   'P015001': 73.0,
#   'P017001': 2.32,
#   'P031001': 36.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06061'},
#  {'NAME': 'ZCTA5 06062, Connecticut',
#   'P003001': 17715.0,
#   'P003002': 16093.0,
#   'P003003': 533.0,
#   'P003004': 24.0,
#   'P003005': 382.0,
#   'P003006': 6.0,
#   'P003007': 372.0,
#   'P003008': 305.0,
#   'P004002': 16620.0,
#   'P013001': 42.0,
#   'P013002': 40.9,
#   'P013003': 43.1,
#   'P015001': 7581.0,
#   'P017001': 2.32,
#   'P031001': 3467.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06062'},
#  {'NAME': 'ZCTA5 06063, Connecticut',
#   'P003001': 3285.0,
#   'P003002': 3200.0,
#   'P003003': 9.0,
#   'P003004': 0.0,
#   'P003005': 20.0,
#   'P003006': 0.0,
#   'P003007': 17.0,
#   'P003008': 39.0,
#   'P004002': 3236.0,
#   'P013001': 44.8,
#   'P013002': 44.6,
#   'P013003': 45.0,
#   'P015001': 1260.0,
#   'P017001': 2.6,
#   'P031001': 762.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06063'},
#  {'NAME': 'ZCTA5 06065, Connecticut',
#   'P003001': 882.0,
#   'P003002': 865.0,
#   'P003003': 6.0,
#   'P003004': 0.0,
#   'P003005': 4.0,
#   'P003006': 0.0,
#   'P003007': 4.0,
#   'P003008': 3.0,
#   'P004002': 871.0,
#   'P013001': 44.5,
#   'P013002': 44.7,
#   'P013003': 44.4,
#   'P015001': 328.0,
#   'P017001': 2.69,
#   'P031001': 205.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06065'},
#  {'NAME': 'ZCTA5 06066, Connecticut',
#   'P003001': 29219.0,
#   'P003002': 24858.0,
#   'P003003': 1698.0,
#   'P003004': 68.0,
#   'P003005': 1266.0,
#   'P003006': 10.0,
#   'P003007': 584.0,
#   'P003008': 735.0,
#   'P004002': 27304.0,
#   'P013001': 40.2,
#   'P013002': 39.1,
#   'P013003': 41.2,
#   'P015001': 12991.0,
#   'P017001': 2.22,
#   'P031001': 5670.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06066'},
#  {'NAME': 'ZCTA5 06067, Connecticut',
#   'P003001': 19709.0,
#   'P003002': 16380.0,
#   'P003003': 740.0,
#   'P003004': 43.0,
#   'P003005': 1943.0,
#   'P003006': 1.0,
#   'P003007': 273.0,
#   'P003008': 329.0,
#   'P004002': 18648.0,
#   'P013001': 44.0,
#   'P013002': 42.7,
#   'P013003': 45.3,
#   'P015001': 8307.0,
#   'P017001': 2.28,
#   'P031001': 3756.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06067'},
#  {'NAME': 'ZCTA5 06068, Connecticut',
#   'P003001': 1612.0,
#   'P003002': 1544.0,
#   'P003003': 15.0,
#   'P003004': 3.0,
#   'P003005': 17.0,
#   'P003006': 0.0,
#   'P003007': 6.0,
#   'P003008': 27.0,
#   'P004002': 1569.0,
#   'P013001': 56.1,
#   'P013002': 53.0,
#   'P013003': 57.8,
#   'P015001': 707.0,
#   'P017001': 1.99,
#   'P031001': 211.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06068'},
#  {'NAME': 'ZCTA5 06069, Connecticut',
#   'P003001': 2535.0,
#   'P003002': 2427.0,
#   'P003003': 43.0,
#   'P003004': 2.0,
#   'P003005': 20.0,
#   'P003006': 0.0,
#   'P003007': 18.0,
#   'P003008': 25.0,
#   'P004002': 2486.0,
#   'P013001': 51.6,
#   'P013002': 51.3,
#   'P013003': 52.0,
#   'P015001': 1136.0,
#   'P017001': 2.13,
#   'P031001': 404.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06069'},
#  {'NAME': 'ZCTA5 06070, Connecticut',
#   'P003001': 15104.0,
#   'P003002': 13928.0,
#   'P003003': 251.0,
#   'P003004': 12.0,
#   'P003005': 570.0,
#   'P003006': 3.0,
#   'P003007': 93.0,
#   'P003008': 247.0,
#   'P004002': 14626.0,
#   'P013001': 44.1,
#   'P013002': 42.4,
#   'P013003': 45.3,
#   'P015001': 5589.0,
#   'P017001': 2.64,
#   'P031001': 4080.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06070'},
#  {'NAME': 'ZCTA5 06071, Connecticut',
#   'P003001': 11645.0,
#   'P003002': 9764.0,
#   'P003003': 995.0,
#   'P003004': 17.0,
#   'P003005': 91.0,
#   'P003006': 3.0,
#   'P003007': 660.0,
#   'P003008': 115.0,
#   'P004002': 10794.0,
#   'P013001': 43.0,
#   'P013002': 40.8,
#   'P013003': 46.0,
#   'P015001': 3344.0,
#   'P017001': 2.73,
#   'P031001': 2168.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06071'},
#  {'NAME': 'ZCTA5 06073, Connecticut',
#   'P003001': 5651.0,
#   'P003002': 5182.0,
#   'P003003': 69.0,
#   'P003004': 4.0,
#   'P003005': 264.0,
#   'P003006': 0.0,
#   'P003007': 27.0,
#   'P003008': 105.0,
#   'P004002': 5483.0,
#   'P013001': 43.9,
#   'P013002': 43.9,
#   'P013003': 43.8,
#   'P015001': 2038.0,
#   'P017001': 2.77,
#   'P031001': 1665.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06073'},
#  {'NAME': 'ZCTA5 06074, Connecticut',
#   'P003001': 25705.0,
#   'P003002': 21743.0,
#   'P003003': 987.0,
#   'P003004': 46.0,
#   'P003005': 2082.0,
#   'P003006': 13.0,
#   'P003007': 321.0,
#   'P003008': 513.0,
#   'P004002': 24608.0,
#   'P013001': 43.3,
#   'P013002': 41.7,
#   'P013003': 44.7,
#   'P015001': 9916.0,
#   'P017001': 2.58,
#   'P031001': 6194.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06074'},
#  {'NAME': 'ZCTA5 06076, Connecticut',
#   'P003001': 12659.0,
#   'P003002': 12079.0,
#   'P003003': 87.0,
#   'P003004': 22.0,
#   'P003005': 136.0,
#   'P003006': 1.0,
#   'P003007': 98.0,
#   'P003008': 236.0,
#   'P004002': 12281.0,
#   'P013001': 41.8,
#   'P013002': 41.3,
#   'P013003': 42.3,
#   'P015001': 5060.0,
#   'P017001': 2.5,
#   'P031001': 2831.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06076'},
#  {'NAME': 'ZCTA5 06078, Connecticut',
#   'P003001': 12413.0,
#   'P003002': 10292.0,
#   'P003003': 1195.0,
#   'P003004': 21.0,
#   'P003005': 182.0,
#   'P003006': 5.0,
#   'P003007': 587.0,
#   'P003008': 131.0,
#   'P004002': 11589.0,
#   'P013001': 40.8,
#   'P013002': 37.8,
#   'P013003': 44.8,
#   'P015001': 3867.0,
#   'P017001': 2.54,
#   'P031001': 2451.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06078'},
#  {'NAME': 'ZCTA5 06081, Connecticut',
#   'P003001': 1381.0,
#   'P003002': 1223.0,
#   'P003003': 76.0,
#   'P003004': 1.0,
#   'P003005': 32.0,
#   'P003006': 0.0,
#   'P003007': 16.0,
#   'P003008': 33.0,
#   'P004002': 1316.0,
#   'P013001': 39.6,
#   'P013002': 38.7,
#   'P013003': 40.5,
#   'P015001': 620.0,
#   'P017001': 2.23,
#   'P031001': 329.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06081'},
#  {'NAME': 'ZCTA5 06082, Connecticut',
#   'P003001': 44654.0,
#   'P003002': 38497.0,
#   'P003003': 2755.0,
#   'P003004': 75.0,
#   'P003005': 869.0,
#   'P003006': 18.0,
#   'P003007': 1575.0,
#   'P003008': 865.0,
#   'P004002': 41648.0,
#   'P013001': 40.4,
#   'P013002': 38.4,
#   'P013003': 43.1,
#   'P015001': 16794.0,
#   'P017001': 2.43,
#   'P031001': 8787.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06082'},
#  {'NAME': 'ZCTA5 06084, Connecticut',
#   'P003001': 15067.0,
#   'P003002': 14264.0,
#   'P003003': 173.0,
#   'P003004': 12.0,
#   'P003005': 353.0,
#   'P003006': 4.0,
#   'P003007': 99.0,
#   'P003008': 162.0,
#   'P004002': 14731.0,
#   'P013001': 41.6,
#   'P013002': 41.2,
#   'P013003': 42.1,
#   'P015001': 5318.0,
#   'P017001': 2.81,
#   'P031001': 4046.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06084'},
#  {'NAME': 'ZCTA5 06085, Connecticut',
#   'P003001': 7276.0,
#   'P003002': 6536.0,
#   'P003003': 156.0,
#   'P003004': 9.0,
#   'P003005': 430.0,
#   'P003006': 0.0,
#   'P003007': 45.0,
#   'P003008': 100.0,
#   'P004002': 6996.0,
#   'P013001': 42.2,
#   'P013002': 40.6,
#   'P013003': 43.5,
#   'P015001': 2858.0,
#   'P017001': 2.54,
#   'P031001': 1803.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06085'},
#  {'NAME': 'ZCTA5 06088, Connecticut',
#   'P003001': 4936.0,
#   'P003002': 4057.0,
#   'P003003': 292.0,
#   'P003004': 3.0,
#   'P003005': 405.0,
#   'P003006': 0.0,
#   'P003007': 74.0,
#   'P003008': 105.0,
#   'P004002': 4700.0,
#   'P013001': 45.6,
#   'P013002': 43.6,
#   'P013003': 47.6,
#   'P015001': 2206.0,
#   'P017001': 2.13,
#   'P031001': 744.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06088'},
#  {'NAME': 'ZCTA5 06089, Connecticut',
#   'P003001': 2813.0,
#   'P003002': 2511.0,
#   'P003003': 44.0,
#   'P003004': 1.0,
#   'P003005': 181.0,
#   'P003006': 0.0,
#   'P003007': 16.0,
#   'P003008': 60.0,
#   'P004002': 2724.0,
#   'P013001': 42.8,
#   'P013002': 40.8,
#   'P013003': 44.2,
#   'P015001': 1140.0,
#   'P017001': 2.46,
#   'P031001': 730.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06089'},
#  {'NAME': 'ZCTA5 06090, Connecticut',
#   'P003001': 1232.0,
#   'P003002': 1207.0,
#   'P003003': 11.0,
#   'P003004': 3.0,
#   'P003005': 3.0,
#   'P003006': 0.0,
#   'P003007': 4.0,
#   'P003008': 4.0,
#   'P004002': 1221.0,
#   'P013001': 45.5,
#   'P013002': 44.6,
#   'P013003': 46.1,
#   'P015001': 438.0,
#   'P017001': 2.8,
#   'P031001': 307.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06090'},
#  {'NAME': 'ZCTA5 06091, Connecticut',
#   'P003001': 140.0,
#   'P003002': 131.0,
#   'P003003': 0.0,
#   'P003004': 0.0,
#   'P003005': 3.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 6.0,
#   'P004002': 140.0,
#   'P013001': 49.5,
#   'P013002': 48.5,
#   'P013003': 49.8,
#   'P015001': 57.0,
#   'P017001': 2.46,
#   'P031001': 26.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06091'},
#  {'NAME': 'ZCTA5 06092, Connecticut',
#   'P003001': 4203.0,
#   'P003002': 3970.0,
#   'P003003': 34.0,
#   'P003004': 7.0,
#   'P003005': 106.0,
#   'P003006': 1.0,
#   'P003007': 23.0,
#   'P003008': 62.0,
#   'P004002': 4098.0,
#   'P013001': 43.5,
#   'P013002': 43.1,
#   'P013003': 44.1,
#   'P015001': 1424.0,
#   'P017001': 2.95,
#   'P031001': 1301.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06092'},
#  {'NAME': 'ZCTA5 06093, Connecticut',
#   'P003001': 3322.0,
#   'P003002': 3207.0,
#   'P003003': 34.0,
#   'P003004': 3.0,
#   'P003005': 22.0,
#   'P003006': 1.0,
#   'P003007': 3.0,
#   'P003008': 52.0,
#   'P004002': 3260.0,
#   'P013001': 45.8,
#   'P013002': 46.2,
#   'P013003': 45.5,
#   'P015001': 1288.0,
#   'P017001': 2.58,
#   'P031001': 726.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06093'},
#  {'NAME': 'ZCTA5 06095, Connecticut',
#   'P003001': 29079.0,
#   'P003002': 15896.0,
#   'P003003': 9997.0,
#   'P003004': 61.0,
#   'P003005': 1300.0,
#   'P003006': 2.0,
#   'P003007': 891.0,
#   'P003008': 932.0,
#   'P004002': 26631.0,
#   'P013001': 43.1,
#   'P013002': 41.1,
#   'P013003': 44.6,
#   'P015001': 11246.0,
#   'P017001': 2.54,
#   'P031001': 6265.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06095'},
#  {'NAME': 'ZCTA5 06096, Connecticut',
#   'P003001': 12498.0,
#   'P003002': 10728.0,
#   'P003003': 605.0,
#   'P003004': 15.0,
#   'P003005': 667.0,
#   'P003006': 0.0,
#   'P003007': 157.0,
#   'P003008': 326.0,
#   'P004002': 11922.0,
#   'P013001': 43.0,
#   'P013002': 42.0,
#   'P013003': 44.0,
#   'P015001': 5223.0,
#   'P017001': 2.38,
#   'P031001': 2567.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06096'},
#  {'NAME': 'ZCTA5 06098, Connecticut',
#   'P003001': 12426.0,
#   'P003002': 11622.0,
#   'P003003': 203.0,
#   'P003004': 26.0,
#   'P003005': 115.0,
#   'P003006': 4.0,
#   'P003007': 229.0,
#   'P003008': 227.0,
#   'P004002': 11833.0,
#   'P013001': 44.1,
#   'P013002': 42.8,
#   'P013003': 45.2,
#   'P015001': 5306.0,
#   'P017001': 2.32,
#   'P031001': 2555.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06098'},
#  {'NAME': 'ZCTA5 06103, Connecticut',
#   'P003001': 1410.0,
#   'P003002': 897.0,
#   'P003003': 183.0,
#   'P003004': 5.0,
#   'P003005': 205.0,
#   'P003006': 3.0,
#   'P003007': 83.0,
#   'P003008': 34.0,
#   'P004002': 1268.0,
#   'P013001': 31.1,
#   'P013002': 32.0,
#   'P013003': 29.8,
#   'P015001': 869.0,
#   'P017001': 1.43,
#   'P031001': 66.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06103'},
#  {'NAME': 'ZCTA5 06105, Connecticut',
#   'P003001': 19392.0,
#   'P003002': 6688.0,
#   'P003003': 7795.0,
#   'P003004': 105.0,
#   'P003005': 1243.0,
#   'P003006': 10.0,
#   'P003007': 2780.0,
#   'P003008': 771.0,
#   'P004002': 14084.0,
#   'P013001': 34.0,
#   'P013002': 34.1,
#   'P013003': 33.8,
#   'P015001': 9832.0,
#   'P017001': 1.91,
#   'P031001': 3652.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06105'},
#  {'NAME': 'ZCTA5 06106, Connecticut',
#   'P003001': 39902.0,
#   'P003002': 14676.0,
#   'P003003': 8347.0,
#   'P003004': 305.0,
#   'P003005': 1306.0,
#   'P003006': 30.0,
#   'P003007': 13381.0,
#   'P003008': 1857.0,
#   'P004002': 15426.0,
#   'P013001': 29.7,
#   'P013002': 28.7,
#   'P013003': 30.6,
#   'P015001': 13742.0,
#   'P017001': 2.66,
#   'P031001': 10384.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06106'},
#  {'NAME': 'ZCTA5 06107, Connecticut',
#   'P003001': 18786.0,
#   'P003002': 16964.0,
#   'P003003': 505.0,
#   'P003004': 20.0,
#   'P003005': 813.0,
#   'P003006': 9.0,
#   'P003007': 147.0,
#   'P003008': 328.0,
#   'P004002': 18061.0,
#   'P013001': 43.8,
#   'P013002': 42.3,
#   'P013003': 45.0,
#   'P015001': 7554.0,
#   'P017001': 2.46,
#   'P031001': 4626.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06107'},
#  {'NAME': 'ZCTA5 06108, Connecticut',
#   'P003001': 24307.0,
#   'P003002': 10231.0,
#   'P003003': 7939.0,
#   'P003004': 108.0,
#   'P003005': 1228.0,
#   'P003006': 18.0,
#   'P003007': 3776.0,
#   'P003008': 1007.0,
#   'P004002': 16844.0,
#   'P013001': 35.2,
#   'P013002': 33.6,
#   'P013003': 36.6,
#   'P015001': 9212.0,
#   'P017001': 2.59,
#   'P031001': 6124.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06108'},
#  {'NAME': 'ZCTA5 06109, Connecticut',
#   'P003001': 26668.0,
#   'P003002': 23876.0,
#   'P003003': 840.0,
#   'P003004': 31.0,
#   'P003005': 765.0,
#   'P003006': 4.0,
#   'P003007': 699.0,
#   'P003008': 453.0,
#   'P004002': 24483.0,
#   'P013001': 45.2,
#   'P013002': 43.3,
#   'P013003': 46.7,
#   'P015001': 11204.0,
#   'P017001': 2.36,
#   'P031001': 5534.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06109'},
#  {'NAME': 'ZCTA5 06110, Connecticut',
#   'P003001': 12650.0,
#   'P003002': 7896.0,
#   'P003003': 1426.0,
#   'P003004': 33.0,
#   'P003005': 1612.0,
#   'P003006': 1.0,
#   'P003007': 1174.0,
#   'P003008': 508.0,
#   'P004002': 10004.0,
#   'P013001': 38.7,
#   'P013002': 36.5,
#   'P013003': 40.3,
#   'P015001': 5040.0,
#   'P017001': 2.51,
#   'P031001': 2905.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06110'},
#  {'NAME': 'ZCTA5 06111, Connecticut',
#   'P003001': 30562.0,
#   'P003002': 26436.0,
#   'P003003': 1075.0,
#   'P003004': 48.0,
#   'P003005': 1736.0,
#   'P003006': 4.0,
#   'P003007': 642.0,
#   'P003008': 621.0,
#   'P004002': 28254.0,
#   'P013001': 43.7,
#   'P013002': 41.7,
#   'P013003': 45.4,
#   'P015001': 12550.0,
#   'P017001': 2.4,
#   'P031001': 6064.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06111'},
#  {'NAME': 'ZCTA5 06112, Connecticut',
#   'P003001': 22879.0,
#   'P003002': 2026.0,
#   'P003003': 18537.0,
#   'P003004': 100.0,
#   'P003005': 78.0,
#   'P003006': 5.0,
#   'P003007': 1440.0,
#   'P003008': 693.0,
#   'P004002': 19943.0,
#   'P013001': 29.8,
#   'P013002': 26.2,
#   'P013003': 32.5,
#   'P015001': 7485.0,
#   'P017001': 2.83,
#   'P031001': 6267.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06112'},
#  {'NAME': 'ZCTA5 06114, Connecticut',
#   'P003001': 27449.0,
#   'P003002': 10732.0,
#   'P003003': 5462.0,
#   'P003004': 176.0,
#   'P003005': 538.0,
#   'P003006': 10.0,
#   'P003007': 9061.0,
#   'P003008': 1470.0,
#   'P004002': 11035.0,
#   'P013001': 30.8,
#   'P013002': 29.5,
#   'P013003': 32.0,
#   'P015001': 9419.0,
#   'P017001': 2.89,
#   'P031001': 7975.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06114'},
#  {'NAME': 'ZCTA5 06117, Connecticut',
#   'P003001': 17267.0,
#   'P003002': 14401.0,
#   'P003003': 995.0,
#   'P003004': 18.0,
#   'P003005': 1235.0,
#   'P003006': 2.0,
#   'P003007': 259.0,
#   'P003008': 357.0,
#   'P004002': 16464.0,
#   'P013001': 42.3,
#   'P013002': 40.3,
#   'P013003': 44.1,
#   'P015001': 5693.0,
#   'P017001': 2.53,
#   'P031001': 3707.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06117'},
#  {'NAME': 'ZCTA5 06118, Connecticut',
#   'P003001': 26956.0,
#   'P003002': 16056.0,
#   'P003003': 5403.0,
#   'P003004': 104.0,
#   'P003005': 1722.0,
#   'P003006': 17.0,
#   'P003007': 2750.0,
#   'P003008': 904.0,
#   'P004002': 21186.0,
#   'P013001': 40.2,
#   'P013002': 38.5,
#   'P013003': 41.7,
#   'P015001': 10987.0,
#   'P017001': 2.43,
#   'P031001': 5857.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06118'},
#  {'NAME': 'ZCTA5 06119, Connecticut',
#   'P003001': 15474.0,
#   'P003002': 11764.0,
#   'P003003': 1244.0,
#   'P003004': 46.0,
#   'P003005': 1021.0,
#   'P003006': 12.0,
#   'P003007': 857.0,
#   'P003008': 530.0,
#   'P004002': 13441.0,
#   'P013001': 37.4,
#   'P013002': 35.3,
#   'P013003': 39.1,
#   'P015001': 6748.0,
#   'P017001': 2.25,
#   'P031001': 3454.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06119'},
#  {'NAME': 'ZCTA5 06120, Connecticut',
#   'P003001': 12887.0,
#   'P003002': 1587.0,
#   'P003003': 7790.0,
#   'P003004': 82.0,
#   'P003005': 58.0,
#   'P003006': 4.0,
#   'P003007': 2919.0,
#   'P003008': 447.0,
#   'P004002': 7997.0,
#   'P013001': 28.7,
#   'P013002': 27.7,
#   'P013003': 29.9,
#   'P015001': 4023.0,
#   'P017001': 2.84,
#   'P031001': 3951.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06120'},
#  {'NAME': 'ZCTA5 06160, Connecticut',
#   'P003001': 0.0,
#   'P003002': 0.0,
#   'P003003': 0.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 0.0,
#   'P004002': 0.0,
#   'P013001': 0.0,
#   'P013002': 0.0,
#   'P013003': 0.0,
#   'P015001': 0.0,
#   'P017001': 0.0,
#   'P031001': 0.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06160'},
#  {'NAME': 'ZCTA5 06226, Connecticut',
#   'P003001': 20114.0,
#   'P003002': 13205.0,
#   'P003003': 1484.0,
#   'P003004': 128.0,
#   'P003005': 445.0,
#   'P003006': 17.0,
#   'P003007': 4064.0,
#   'P003008': 771.0,
#   'P004002': 11970.0,
#   'P013001': 26.6,
#   'P013002': 25.9,
#   'P013003': 27.3,
#   'P015001': 6782.0,
#   'P017001': 2.55,
#   'P031001': 4533.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06226'},
#  {'NAME': 'ZCTA5 06231, Connecticut',
#   'P003001': 4083.0,
#   'P003002': 3935.0,
#   'P003003': 27.0,
#   'P003004': 8.0,
#   'P003005': 24.0,
#   'P003006': 4.0,
#   'P003007': 4.0,
#   'P003008': 81.0,
#   'P004002': 3983.0,
#   'P013001': 41.2,
#   'P013002': 40.6,
#   'P013003': 41.8,
#   'P015001': 1449.0,
#   'P017001': 2.81,
#   'P031001': 1077.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06231'},
#  {'NAME': 'ZCTA5 06232, Connecticut',
#   'P003001': 3297.0,
#   'P003002': 3163.0,
#   'P003003': 36.0,
#   'P003004': 4.0,
#   'P003005': 37.0,
#   'P003006': 0.0,
#   'P003007': 17.0,
#   'P003008': 40.0,
#   'P004002': 3244.0,
#   'P013001': 42.9,
#   'P013002': 41.6,
#   'P013003': 43.8,
#   'P015001': 1241.0,
#   'P017001': 2.65,
#   'P031001': 834.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06232'},
#  {'NAME': 'ZCTA5 06234, Connecticut',
#   'P003001': 8244.0,
#   'P003002': 7639.0,
#   'P003003': 241.0,
#   'P003004': 24.0,
#   'P003005': 88.0,
#   'P003006': 2.0,
#   'P003007': 149.0,
#   'P003008': 101.0,
#   'P004002': 7918.0,
#   'P013001': 40.9,
#   'P013002': 39.5,
#   'P013003': 42.6,
#   'P015001': 3001.0,
#   'P017001': 2.55,
#   'P031001': 1801.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06234'},
#  {'NAME': 'ZCTA5 06235, Connecticut',
#   'P003001': 2257.0,
#   'P003002': 2143.0,
#   'P003003': 21.0,
#   'P003004': 6.0,
#   'P003005': 6.0,
#   'P003006': 0.0,
#   'P003007': 31.0,
#   'P003008': 50.0,
#   'P004002': 2150.0,
#   'P013001': 43.0,
#   'P013002': 42.8,
#   'P013003': 43.1,
#   'P015001': 898.0,
#   'P017001': 2.51,
#   'P031001': 455.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06235'},
#  {'NAME': 'ZCTA5 06237, Connecticut',
#   'P003001': 5492.0,
#   'P003002': 5334.0,
#   'P003003': 36.0,
#   'P003004': 6.0,
#   'P003005': 36.0,
#   'P003006': 0.0,
#   'P003007': 31.0,
#   'P003008': 49.0,
#   'P004002': 5333.0,
#   'P013001': 45.6,
#   'P013002': 45.8,
#   'P013003': 45.4,
#   'P015001': 2157.0,
#   'P017001': 2.53,
#   'P031001': 1160.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06237'},
#  {'NAME': 'ZCTA5 06238, Connecticut',
#   'P003001': 12428.0,
#   'P003002': 11903.0,
#   'P003003': 128.0,
#   'P003004': 30.0,
#   'P003005': 107.0,
#   'P003006': 1.0,
#   'P003007': 68.0,
#   'P003008': 191.0,
#   'P004002': 12103.0,
#   'P013001': 41.5,
#   'P013002': 40.7,
#   'P013003': 42.1,
#   'P015001': 4780.0,
#   'P017001': 2.59,
#   'P031001': 2900.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06238'},
#  {'NAME': 'ZCTA5 06239, Connecticut',
#   'P003001': 11183.0,
#   'P003002': 10360.0,
#   'P003003': 198.0,
#   'P003004': 51.0,
#   'P003005': 208.0,
#   'P003006': 2.0,
#   'P003007': 93.0,
#   'P003008': 271.0,
#   'P004002': 10799.0,
#   'P013001': 39.8,
#   'P013002': 38.4,
#   'P013003': 41.1,
#   'P015001': 4359.0,
#   'P017001': 2.51,
#   'P031001': 2468.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06239'},
#  {'NAME': 'ZCTA5 06241, Connecticut',
#   'P003001': 6650.0,
#   'P003002': 6252.0,
#   'P003003': 66.0,
#   'P003004': 23.0,
#   'P003005': 109.0,
#   'P003006': 0.0,
#   'P003007': 37.0,
#   'P003008': 163.0,
#   'P004002': 6481.0,
#   'P013001': 39.4,
#   'P013002': 38.2,
#   'P013003': 40.9,
#   'P015001': 2542.0,
#   'P017001': 2.57,
#   'P031001': 1552.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06241'},
#  {'NAME': 'ZCTA5 06242, Connecticut',
#   'P003001': 1408.0,
#   'P003002': 1366.0,
#   'P003003': 1.0,
#   'P003004': 3.0,
#   'P003005': 15.0,
#   'P003006': 0.0,
#   'P003007': 3.0,
#   'P003008': 20.0,
#   'P004002': 1387.0,
#   'P013001': 44.8,
#   'P013002': 43.5,
#   'P013003': 46.2,
#   'P015001': 552.0,
#   'P017001': 2.55,
#   'P031001': 300.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06242'},
#  {'NAME': 'ZCTA5 06243, Connecticut',
#   'P003001': 60.0,
#   'P003002': 59.0,
#   'P003003': 0.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 1.0,
#   'P003008': 0.0,
#   'P004002': 57.0,
#   'P013001': 34.0,
#   'P013002': 33.5,
#   'P013003': 34.5,
#   'P015001': 23.0,
#   'P017001': 2.61,
#   'P031001': 12.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06243'},
#  {'NAME': 'ZCTA5 06247, Connecticut',
#   'P003001': 2841.0,
#   'P003002': 2745.0,
#   'P003003': 9.0,
#   'P003004': 11.0,
#   'P003005': 18.0,
#   'P003006': 0.0,
#   'P003007': 16.0,
#   'P003008': 42.0,
#   'P004002': 2765.0,
#   'P013001': 44.1,
#   'P013002': 43.4,
#   'P013003': 45.1,
#   'P015001': 1093.0,
#   'P017001': 2.6,
#   'P031001': 604.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06247'},
#  {'NAME': 'ZCTA5 06248, Connecticut',
#   'P003001': 5603.0,
#   'P003002': 5432.0,
#   'P003003': 21.0,
#   'P003004': 9.0,
#   'P003005': 71.0,
#   'P003006': 0.0,
#   'P003007': 22.0,
#   'P003008': 48.0,
#   'P004002': 5479.0,
#   'P013001': 42.3,
#   'P013002': 41.9,
#   'P013003': 42.6,
#   'P015001': 1949.0,
#   'P017001': 2.87,
#   'P031001': 1629.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06248'},
#  {'NAME': 'ZCTA5 06249, Connecticut',
#   'P003001': 7308.0,
#   'P003002': 7004.0,
#   'P003003': 80.0,
#   'P003004': 43.0,
#   'P003005': 41.0,
#   'P003006': 0.0,
#   'P003007': 39.0,
#   'P003008': 101.0,
#   'P004002': 7108.0,
#   'P013001': 42.7,
#   'P013002': 42.7,
#   'P013003': 42.6,
#   'P015001': 2644.0,
#   'P017001': 2.72,
#   'P031001': 1761.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06249'},
#  {'NAME': 'ZCTA5 06250, Connecticut',
#   'P003001': 4821.0,
#   'P003002': 4273.0,
#   'P003003': 87.0,
#   'P003004': 10.0,
#   'P003005': 261.0,
#   'P003006': 1.0,
#   'P003007': 48.0,
#   'P003008': 141.0,
#   'P004002': 4589.0,
#   'P013001': 42.4,
#   'P013002': 40.6,
#   'P013003': 43.7,
#   'P015001': 1915.0,
#   'P017001': 2.51,
#   'P031001': 1092.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06250'},
#  {'NAME': 'ZCTA5 06254, Connecticut',
#   'P003001': 1922.0,
#   'P003002': 1841.0,
#   'P003003': 12.0,
#   'P003004': 11.0,
#   'P003005': 22.0,
#   'P003006': 0.0,
#   'P003007': 16.0,
#   'P003008': 20.0,
#   'P004002': 1879.0,
#   'P013001': 44.1,
#   'P013002': 43.2,
#   'P013003': 44.9,
#   'P015001': 729.0,
#   'P017001': 2.62,
#   'P031001': 418.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06254'},
#  {'NAME': 'ZCTA5 06255, Connecticut',
#   'P003001': 4744.0,
#   'P003002': 4501.0,
#   'P003003': 29.0,
#   'P003004': 25.0,
#   'P003005': 36.0,
#   'P003006': 2.0,
#   'P003007': 44.0,
#   'P003008': 107.0,
#   'P004002': 4648.0,
#   'P013001': 42.1,
#   'P013002': 41.1,
#   'P013003': 43.1,
#   'P015001': 1882.0,
#   'P017001': 2.5,
#   'P031001': 1068.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06255'},
#  {'NAME': 'ZCTA5 06256, Connecticut',
#   'P003001': 2154.0,
#   'P003002': 1942.0,
#   'P003003': 46.0,
#   'P003004': 18.0,
#   'P003005': 15.0,
#   'P003006': 0.0,
#   'P003007': 84.0,
#   'P003008': 49.0,
#   'P004002': 1963.0,
#   'P013001': 49.5,
#   'P013002': 47.4,
#   'P013003': 51.0,
#   'P015001': 983.0,
#   'P017001': 2.18,
#   'P031001': 348.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06256'},
#  {'NAME': 'ZCTA5 06259, Connecticut',
#   'P003001': 4498.0,
#   'P003002': 4298.0,
#   'P003003': 27.0,
#   'P003004': 8.0,
#   'P003005': 71.0,
#   'P003006': 0.0,
#   'P003007': 15.0,
#   'P003008': 79.0,
#   'P004002': 4405.0,
#   'P013001': 41.9,
#   'P013002': 41.6,
#   'P013003': 42.2,
#   'P015001': 1676.0,
#   'P017001': 2.58,
#   'P031001': 1106.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06259'},
#  {'NAME': 'ZCTA5 06260, Connecticut',
#   'P003001': 9510.0,
#   'P003002': 8946.0,
#   'P003003': 126.0,
#   'P003004': 60.0,
#   'P003005': 96.0,
#   'P003006': 3.0,
#   'P003007': 61.0,
#   'P003008': 218.0,
#   'P004002': 9228.0,
#   'P013001': 39.9,
#   'P013002': 37.3,
#   'P013003': 43.1,
#   'P015001': 3923.0,
#   'P017001': 2.33,
#   'P031001': 2098.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06260'},
#  {'NAME': 'ZCTA5 06262, Connecticut',
#   'P003001': 586.0,
#   'P003002': 573.0,
#   'P003003': 3.0,
#   'P003004': 2.0,
#   'P003005': 4.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 4.0,
#   'P004002': 566.0,
#   'P013001': 49.8,
#   'P013002': 48.2,
#   'P013003': 51.3,
#   'P015001': 270.0,
#   'P017001': 2.17,
#   'P031001': 93.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06262'},
#  {'NAME': 'ZCTA5 06263, Connecticut',
#   'P003001': 345.0,
#   'P003002': 315.0,
#   'P003003': 9.0,
#   'P003004': 4.0,
#   'P003005': 2.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 15.0,
#   'P004002': 340.0,
#   'P013001': 31.8,
#   'P013002': 33.3,
#   'P013003': 31.0,
#   'P015001': 130.0,
#   'P017001': 2.65,
#   'P031001': 100.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06263'},
#  {'NAME': 'ZCTA5 06264, Connecticut',
#   'P003001': 166.0,
#   'P003002': 155.0,
#   'P003003': 0.0,
#   'P003004': 1.0,
#   'P003005': 2.0,
#   'P003006': 0.0,
#   'P003007': 2.0,
#   'P003008': 6.0,
#   'P004002': 157.0,
#   'P013001': 45.3,
#   'P013002': 45.2,
#   'P013003': 46.3,
#   'P015001': 68.0,
#   'P017001': 2.44,
#   'P031001': 36.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06264'},
#  {'NAME': 'ZCTA5 06266, Connecticut',
#   'P003001': 495.0,
#   'P003002': 451.0,
#   'P003003': 17.0,
#   'P003004': 1.0,
#   'P003005': 3.0,
#   'P003006': 1.0,
#   'P003007': 16.0,
#   'P003008': 6.0,
#   'P004002': 440.0,
#   'P013001': 41.4,
#   'P013002': 41.8,
#   'P013003': 40.9,
#   'P015001': 194.0,
#   'P017001': 2.55,
#   'P031001': 94.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06266'},
#  {'NAME': 'ZCTA5 06268, Connecticut',
#   'P003001': 11481.0,
#   'P003002': 9236.0,
#   'P003003': 706.0,
#   'P003004': 13.0,
#   'P003005': 914.0,
#   'P003006': 2.0,
#   'P003007': 374.0,
#   'P003008': 236.0,
#   'P004002': 10748.0,
#   'P013001': 24.8,
#   'P013002': 25.1,
#   'P013003': 24.0,
#   'P015001': 3466.0,
#   'P017001': 2.43,
#   'P031001': 1362.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06268'},
#  {'NAME': 'ZCTA5 06269, Connecticut',
#   'P003001': 9844.0,
#   'P003002': 7882.0,
#   'P003003': 565.0,
#   'P003004': 10.0,
#   'P003005': 944.0,
#   'P003006': 6.0,
#   'P003007': 174.0,
#   'P003008': 263.0,
#   'P004002': 9258.0,
#   'P013001': 20.1,
#   'P013002': 20.2,
#   'P013003': 20.0,
#   'P015001': 23.0,
#   'P017001': 1.87,
#   'P031001': 18.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06269'},
#  {'NAME': 'ZCTA5 06277, Connecticut',
#   'P003001': 4140.0,
#   'P003002': 4010.0,
#   'P003003': 25.0,
#   'P003004': 11.0,
#   'P003005': 26.0,
#   'P003006': 2.0,
#   'P003007': 15.0,
#   'P003008': 51.0,
#   'P004002': 4090.0,
#   'P013001': 42.1,
#   'P013002': 41.7,
#   'P013003': 42.9,
#   'P015001': 1582.0,
#   'P017001': 2.58,
#   'P031001': 906.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06277'},
#  {'NAME': 'ZCTA5 06278, Connecticut',
#   'P003001': 4454.0,
#   'P003002': 4188.0,
#   'P003003': 46.0,
#   'P003004': 16.0,
#   'P003005': 58.0,
#   'P003006': 1.0,
#   'P003007': 55.0,
#   'P003008': 90.0,
#   'P004002': 4290.0,
#   'P013001': 41.9,
#   'P013002': 41.2,
#   'P013003': 42.4,
#   'P015001': 1773.0,
#   'P017001': 2.51,
#   'P031001': 992.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06278'},
#  {'NAME': 'ZCTA5 06279, Connecticut',
#   'P003001': 6041.0,
#   'P003002': 5632.0,
#   'P003003': 48.0,
#   'P003004': 20.0,
#   'P003005': 202.0,
#   'P003006': 1.0,
#   'P003007': 42.0,
#   'P003008': 96.0,
#   'P004002': 5835.0,
#   'P013001': 38.3,
#   'P013002': 37.5,
#   'P013003': 39.0,
#   'P015001': 2423.0,
#   'P017001': 2.48,
#   'P031001': 1120.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06279'},
#  {'NAME': 'ZCTA5 06280, Connecticut',
#   'P003001': 3162.0,
#   'P003002': 2878.0,
#   'P003003': 46.0,
#   'P003004': 9.0,
#   'P003005': 16.0,
#   'P003006': 0.0,
#   'P003007': 119.0,
#   'P003008': 94.0,
#   'P004002': 2832.0,
#   'P013001': 47.0,
#   'P013002': 44.7,
#   'P013003': 49.5,
#   'P015001': 1237.0,
#   'P017001': 2.4,
#   'P031001': 540.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06280'},
#  {'NAME': 'ZCTA5 06281, Connecticut',
#   'P003001': 6930.0,
#   'P003002': 6749.0,
#   'P003003': 23.0,
#   'P003004': 21.0,
#   'P003005': 52.0,
#   'P003006': 0.0,
#   'P003007': 28.0,
#   'P003008': 57.0,
#   'P004002': 6831.0,
#   'P013001': 44.2,
#   'P013002': 43.8,
#   'P013003': 44.7,
#   'P015001': 2747.0,
#   'P017001': 2.52,
#   'P031001': 1598.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06281'},
#  {'NAME': 'ZCTA5 06282, Connecticut',
#   'P003001': 1096.0,
#   'P003002': 1056.0,
#   'P003003': 7.0,
#   'P003004': 4.0,
#   'P003005': 7.0,
#   'P003006': 1.0,
#   'P003007': 2.0,
#   'P003008': 19.0,
#   'P004002': 1076.0,
#   'P013001': 43.3,
#   'P013002': 43.2,
#   'P013003': 43.4,
#   'P015001': 427.0,
#   'P017001': 2.57,
#   'P031001': 258.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06282'},
#  {'NAME': 'ZCTA5 06320, Connecticut',
#   'P003001': 27617.0,
#   'P003002': 16681.0,
#   'P003003': 4814.0,
#   'P003004': 266.0,
#   'P003005': 719.0,
#   'P003006': 44.0,
#   'P003007': 3251.0,
#   'P003008': 1842.0,
#   'P004002': 19802.0,
#   'P013001': 30.3,
#   'P013002': 29.1,
#   'P013003': 31.6,
#   'P015001': 10373.0,
#   'P017001': 2.3,
#   'P031001': 5646.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06320'},
#  {'NAME': 'ZCTA5 06330, Connecticut',
#   'P003001': 3282.0,
#   'P003002': 2981.0,
#   'P003003': 62.0,
#   'P003004': 26.0,
#   'P003005': 35.0,
#   'P003006': 1.0,
#   'P003007': 73.0,
#   'P003008': 104.0,
#   'P004002': 3134.0,
#   'P013001': 39.1,
#   'P013002': 38.8,
#   'P013003': 39.4,
#   'P015001': 1244.0,
#   'P017001': 2.64,
#   'P031001': 786.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06330'},
#  {'NAME': 'ZCTA5 06331, Connecticut',
#   'P003001': 5137.0,
#   'P003002': 4911.0,
#   'P003003': 57.0,
#   'P003004': 21.0,
#   'P003005': 35.0,
#   'P003006': 0.0,
#   'P003007': 13.0,
#   'P003008': 100.0,
#   'P004002': 5043.0,
#   'P013001': 43.2,
#   'P013002': 41.9,
#   'P013003': 44.2,
#   'P015001': 1936.0,
#   'P017001': 2.65,
#   'P031001': 1127.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06331'},
#  {'NAME': 'ZCTA5 06332, Connecticut',
#   'P003001': 258.0,
#   'P003002': 247.0,
#   'P003003': 5.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 6.0,
#   'P003008': 0.0,
#   'P004002': 252.0,
#   'P013001': 41.0,
#   'P013002': 40.3,
#   'P013003': 42.5,
#   'P015001': 97.0,
#   'P017001': 2.66,
#   'P031001': 67.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06332'},
#  {'NAME': 'ZCTA5 06333, Connecticut',
#   'P003001': 6607.0,
#   'P003002': 5639.0,
#   'P003003': 68.0,
#   'P003004': 17.0,
#   'P003005': 664.0,
#   'P003006': 4.0,
#   'P003007': 58.0,
#   'P003008': 157.0,
#   'P004002': 6396.0,
#   'P013001': 43.8,
#   'P013002': 43.2,
#   'P013003': 44.3,
#   'P015001': 2399.0,
#   'P017001': 2.75,
#   'P031001': 1759.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06333'},
#  {'NAME': 'ZCTA5 06334, Connecticut',
#   'P003001': 2592.0,
#   'P003002': 2468.0,
#   'P003003': 29.0,
#   'P003004': 11.0,
#   'P003005': 18.0,
#   'P003006': 0.0,
#   'P003007': 18.0,
#   'P003008': 48.0,
#   'P004002': 2502.0,
#   'P013001': 43.9,
#   'P013002': 43.5,
#   'P013003': 44.4,
#   'P015001': 991.0,
#   'P017001': 2.6,
#   'P031001': 540.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06334'},
#  {'NAME': 'ZCTA5 06335, Connecticut',
#   'P003001': 6729.0,
#   'P003002': 5965.0,
#   'P003003': 178.0,
#   'P003004': 48.0,
#   'P003005': 238.0,
#   'P003006': 3.0,
#   'P003007': 70.0,
#   'P003008': 227.0,
#   'P004002': 6397.0,
#   'P013001': 41.7,
#   'P013002': 40.5,
#   'P013003': 42.9,
#   'P015001': 2524.0,
#   'P017001': 2.66,
#   'P031001': 1668.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06335'},
#  {'NAME': 'ZCTA5 06336, Connecticut',
#   'P003001': 84.0,
#   'P003002': 84.0,
#   'P003003': 0.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 0.0,
#   'P004002': 83.0,
#   'P013001': 41.5,
#   'P013002': 39.0,
#   'P013003': 45.5,
#   'P015001': 34.0,
#   'P017001': 2.47,
#   'P031001': 19.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06336'},
#  {'NAME': 'ZCTA5 06339, Connecticut',
#   'P003001': 8302.0,
#   'P003002': 6868.0,
#   'P003003': 314.0,
#   'P003004': 327.0,
#   'P003005': 292.0,
#   'P003006': 7.0,
#   'P003007': 121.0,
#   'P003008': 373.0,
#   'P004002': 7802.0,
#   'P013001': 39.8,
#   'P013002': 39.3,
#   'P013003': 40.5,
#   'P015001': 3101.0,
#   'P017001': 2.67,
#   'P031001': 1999.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06339'},
#  {'NAME': 'ZCTA5 06340, Connecticut',
#   'P003001': 31242.0,
#   'P003002': 23673.0,
#   'P003003': 2552.0,
#   'P003004': 265.0,
#   'P003005': 2139.0,
#   'P003006': 31.0,
#   'P003007': 824.0,
#   'P003008': 1758.0,
#   'P004002': 27926.0,
#   'P013001': 30.2,
#   'P013002': 27.9,
#   'P013003': 34.1,
#   'P015001': 12136.0,
#   'P017001': 2.29,
#   'P031001': 6580.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06340'},
#  {'NAME': 'ZCTA5 06350, Connecticut',
#   'P003001': 67.0,
#   'P003002': 67.0,
#   'P003003': 0.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 0.0,
#   'P004002': 67.0,
#   'P013001': 45.5,
#   'P013002': 41.5,
#   'P013003': 49.0,
#   'P015001': 26.0,
#   'P017001': 2.58,
#   'P031001': 11.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06350'},
#  {'NAME': 'ZCTA5 06351, Connecticut',
#   'P003001': 16301.0,
#   'P003002': 15048.0,
#   'P003003': 250.0,
#   'P003004': 139.0,
#   'P003005': 331.0,
#   'P003006': 4.0,
#   'P003007': 101.0,
#   'P003008': 428.0,
#   'P004002': 15818.0,
#   'P013001': 40.7,
#   'P013002': 40.0,
#   'P013003': 41.5,
#   'P015001': 6311.0,
#   'P017001': 2.58,
#   'P031001': 3714.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06351'},
#  {'NAME': 'ZCTA5 06353, Connecticut',
#   'P003001': 162.0,
#   'P003002': 142.0,
#   'P003003': 5.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 7.0,
#   'P003008': 8.0,
#   'P004002': 146.0,
#   'P013001': 47.0,
#   'P013002': 48.8,
#   'P013003': 45.3,
#   'P015001': 83.0,
#   'P017001': 1.95,
# ...
#   'P003007': 53.0,
#   'P003008': 84.0,
#   'P004002': 7773.0,
#   'P013001': 42.5,
#   'P013002': 42.1,
#   'P013003': 42.9,
#   'P015001': 3139.0,
#   'P017001': 2.54,
#   'P031001': 1839.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06787'},
#  {'NAME': 'ZCTA5 06790, Connecticut',
#   'P003001': 36482.0,
#   'P003002': 32383.0,
#   'P003003': 975.0,
#   'P003004': 90.0,
#   'P003005': 785.0,
#   'P003006': 9.0,
#   'P003007': 1324.0,
#   'P003008': 916.0,
#   'P004002': 33297.0,
#   'P013001': 42.4,
#   'P013002': 40.7,
#   'P013003': 44.1,
#   'P015001': 15289.0,
#   'P017001': 2.33,
#   'P031001': 7670.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06790'},
#  {'NAME': 'ZCTA5 06791, Connecticut',
#   'P003001': 5666.0,
#   'P003002': 5532.0,
#   'P003003': 13.0,
#   'P003004': 8.0,
#   'P003005': 49.0,
#   'P003006': 4.0,
#   'P003007': 14.0,
#   'P003008': 46.0,
#   'P004002': 5580.0,
#   'P013001': 45.6,
#   'P013002': 45.0,
#   'P013003': 46.3,
#   'P015001': 2179.0,
#   'P017001': 2.59,
#   'P031001': 1290.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06791'},
#  {'NAME': 'ZCTA5 06793, Connecticut',
#   'P003001': 1140.0,
#   'P003002': 1095.0,
#   'P003003': 3.0,
#   'P003004': 0.0,
#   'P003005': 8.0,
#   'P003006': 0.0,
#   'P003007': 13.0,
#   'P003008': 21.0,
#   'P004002': 1103.0,
#   'P013001': 51.5,
#   'P013002': 51.5,
#   'P013003': 51.5,
#   'P015001': 484.0,
#   'P017001': 2.18,
#   'P031001': 190.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06793'},
#  {'NAME': 'ZCTA5 06794, Connecticut',
#   'P003001': 1065.0,
#   'P003002': 1033.0,
#   'P003003': 9.0,
#   'P003004': 0.0,
#   'P003005': 10.0,
#   'P003006': 0.0,
#   'P003007': 4.0,
#   'P003008': 9.0,
#   'P004002': 1012.0,
#   'P013001': 49.7,
#   'P013002': 47.8,
#   'P013003': 51.6,
#   'P015001': 452.0,
#   'P017001': 2.22,
#   'P031001': 219.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06794'},
#  {'NAME': 'ZCTA5 06795, Connecticut',
#   'P003001': 14144.0,
#   'P003002': 13473.0,
#   'P003003': 152.0,
#   'P003004': 33.0,
#   'P003005': 234.0,
#   'P003006': 1.0,
#   'P003007': 88.0,
#   'P003008': 163.0,
#   'P004002': 13733.0,
#   'P013001': 45.0,
#   'P013002': 43.6,
#   'P013003': 46.2,
#   'P015001': 5319.0,
#   'P017001': 2.61,
#   'P031001': 3050.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06795'},
#  {'NAME': 'ZCTA5 06796, Connecticut',
#   'P003001': 1009.0,
#   'P003002': 985.0,
#   'P003003': 2.0,
#   'P003004': 1.0,
#   'P003005': 3.0,
#   'P003006': 0.0,
#   'P003007': 3.0,
#   'P003008': 15.0,
#   'P004002': 979.0,
#   'P013001': 51.3,
#   'P013002': 51.0,
#   'P013003': 51.6,
#   'P015001': 457.0,
#   'P017001': 2.21,
#   'P031001': 183.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06796'},
#  {'NAME': 'ZCTA5 06798, Connecticut',
#   'P003001': 9984.0,
#   'P003002': 9556.0,
#   'P003003': 57.0,
#   'P003004': 33.0,
#   'P003005': 168.0,
#   'P003006': 0.0,
#   'P003007': 38.0,
#   'P003008': 132.0,
#   'P004002': 9739.0,
#   'P013001': 46.9,
#   'P013002': 45.9,
#   'P013003': 47.7,
#   'P015001': 4219.0,
#   'P017001': 2.36,
#   'P031001': 2099.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06798'},
#  {'NAME': 'ZCTA5 06801, Connecticut',
#   'P003001': 18581.0,
#   'P003002': 16502.0,
#   'P003003': 343.0,
#   'P003004': 18.0,
#   'P003005': 833.0,
#   'P003006': 6.0,
#   'P003007': 527.0,
#   'P003008': 352.0,
#   'P004002': 17171.0,
#   'P013001': 41.6,
#   'P013002': 40.4,
#   'P013003': 42.8,
#   'P015001': 6934.0,
#   'P017001': 2.65,
#   'P031001': 4374.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06801'},
#  {'NAME': 'ZCTA5 06804, Connecticut',
#   'P003001': 16466.0,
#   'P003002': 15298.0,
#   'P003003': 177.0,
#   'P003004': 7.0,
#   'P003005': 598.0,
#   'P003006': 0.0,
#   'P003007': 202.0,
#   'P003008': 184.0,
#   'P004002': 15747.0,
#   'P013001': 43.5,
#   'P013002': 42.6,
#   'P013003': 44.2,
#   'P015001': 6136.0,
#   'P017001': 2.68,
#   'P031001': 4109.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06804'},
#  {'NAME': 'ZCTA5 06807, Connecticut',
#   'P003001': 7150.0,
#   'P003002': 6199.0,
#   'P003003': 70.0,
#   'P003004': 4.0,
#   'P003005': 610.0,
#   'P003006': 2.0,
#   'P003007': 104.0,
#   'P003008': 161.0,
#   'P004002': 6632.0,
#   'P013001': 41.0,
#   'P013002': 40.4,
#   'P013003': 41.6,
#   'P015001': 2686.0,
#   'P017001': 2.65,
#   'P031001': 1968.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06807'},
#  {'NAME': 'ZCTA5 06810, Connecticut',
#   'P003001': 49482.0,
#   'P003002': 30430.0,
#   'P003003': 3670.0,
#   'P003004': 235.0,
#   'P003005': 3402.0,
#   'P003006': 20.0,
#   'P003007': 8983.0,
#   'P003008': 2742.0,
#   'P004002': 33107.0,
#   'P013001': 34.0,
#   'P013002': 33.3,
#   'P013003': 35.0,
#   'P015001': 17694.0,
#   'P017001': 2.71,
#   'P031001': 10672.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06810'},
#  {'NAME': 'ZCTA5 06811, Connecticut',
#   'P003001': 31400.0,
#   'P003002': 24761.0,
#   'P003003': 2133.0,
#   'P003004': 91.0,
#   'P003005': 2072.0,
#   'P003006': 10.0,
#   'P003007': 1429.0,
#   'P003008': 904.0,
#   'P004002': 27590.0,
#   'P013001': 40.3,
#   'P013002': 39.5,
#   'P013003': 40.9,
#   'P015001': 11210.0,
#   'P017001': 2.58,
#   'P031001': 6373.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06811'},
#  {'NAME': 'ZCTA5 06812, Connecticut',
#   'P003001': 13881.0,
#   'P003002': 13161.0,
#   'P003003': 149.0,
#   'P003004': 18.0,
#   'P003005': 232.0,
#   'P003006': 8.0,
#   'P003007': 123.0,
#   'P003008': 190.0,
#   'P004002': 13270.0,
#   'P013001': 42.4,
#   'P013002': 41.9,
#   'P013003': 43.0,
#   'P015001': 4802.0,
#   'P017001': 2.89,
#   'P031001': 3778.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06812'},
#  {'NAME': 'ZCTA5 06820, Connecticut',
#   'P003001': 20732.0,
#   'P003002': 19508.0,
#   'P003003': 104.0,
#   'P003004': 20.0,
#   'P003005': 744.0,
#   'P003006': 5.0,
#   'P003007': 121.0,
#   'P003008': 230.0,
#   'P004002': 19989.0,
#   'P013001': 39.1,
#   'P013002': 37.7,
#   'P013003': 40.1,
#   'P015001': 6698.0,
#   'P017001': 3.09,
#   'P031001': 7381.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06820'},
#  {'NAME': 'ZCTA5 06824, Connecticut',
#   'P003001': 33900.0,
#   'P003002': 31582.0,
#   'P003003': 497.0,
#   'P003004': 12.0,
#   'P003005': 1056.0,
#   'P003006': 5.0,
#   'P003007': 306.0,
#   'P003008': 442.0,
#   'P004002': 32469.0,
#   'P013001': 39.0,
#   'P013002': 38.1,
#   'P013003': 39.8,
#   'P015001': 11418.0,
#   'P017001': 2.73,
#   'P031001': 8731.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06824'},
#  {'NAME': 'ZCTA5 06825, Connecticut',
#   'P003001': 21123.0,
#   'P003002': 18744.0,
#   'P003003': 537.0,
#   'P003004': 23.0,
#   'P003005': 983.0,
#   'P003006': 3.0,
#   'P003007': 396.0,
#   'P003008': 437.0,
#   'P004002': 19712.0,
#   'P013001': 40.6,
#   'P013002': 39.2,
#   'P013003': 41.8,
#   'P015001': 7440.0,
#   'P017001': 2.64,
#   'P031001': 5134.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06825'},
#  {'NAME': 'ZCTA5 06830, Connecticut',
#   'P003001': 24027.0,
#   'P003002': 19969.0,
#   'P003003': 875.0,
#   'P003004': 39.0,
#   'P003005': 1644.0,
#   'P003006': 7.0,
#   'P003007': 930.0,
#   'P003008': 563.0,
#   'P004002': 20653.0,
#   'P013001': 42.4,
#   'P013002': 40.2,
#   'P013003': 44.1,
#   'P015001': 9766.0,
#   'P017001': 2.43,
#   'P031001': 5769.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06830'},
#  {'NAME': 'ZCTA5 06831, Connecticut',
#   'P003001': 14792.0,
#   'P003002': 13372.0,
#   'P003003': 167.0,
#   'P003004': 18.0,
#   'P003005': 769.0,
#   'P003006': 1.0,
#   'P003007': 242.0,
#   'P003008': 223.0,
#   'P004002': 13732.0,
#   'P013001': 46.1,
#   'P013002': 45.2,
#   'P013003': 47.0,
#   'P015001': 5408.0,
#   'P017001': 2.67,
#   'P031001': 3612.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06831'},
#  {'NAME': 'ZCTA5 06840, Connecticut',
#   'P003001': 19738.0,
#   'P003002': 18481.0,
#   'P003003': 197.0,
#   'P003004': 30.0,
#   'P003005': 663.0,
#   'P003006': 3.0,
#   'P003007': 96.0,
#   'P003008': 268.0,
#   'P004002': 19168.0,
#   'P013001': 43.0,
#   'P013002': 42.1,
#   'P013003': 43.7,
#   'P015001': 7010.0,
#   'P017001': 2.81,
#   'P031001': 6329.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06840'},
#  {'NAME': 'ZCTA5 06850, Connecticut',
#   'P003001': 18078.0,
#   'P003002': 13226.0,
#   'P003003': 2011.0,
#   'P003004': 76.0,
#   'P003005': 1139.0,
#   'P003006': 8.0,
#   'P003007': 1084.0,
#   'P003008': 534.0,
#   'P004002': 14374.0,
#   'P013001': 39.8,
#   'P013002': 38.8,
#   'P013003': 40.8,
#   'P015001': 7119.0,
#   'P017001': 2.51,
#   'P031001': 3795.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06850'},
#  {'NAME': 'ZCTA5 06851, Connecticut',
#   'P003001': 26703.0,
#   'P003002': 20681.0,
#   'P003003': 2481.0,
#   'P003004': 78.0,
#   'P003005': 1379.0,
#   'P003006': 10.0,
#   'P003007': 1449.0,
#   'P003008': 625.0,
#   'P004002': 22201.0,
#   'P013001': 40.7,
#   'P013002': 39.5,
#   'P013003': 42.2,
#   'P015001': 10548.0,
#   'P017001': 2.5,
#   'P031001': 5575.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06851'},
#  {'NAME': 'ZCTA5 06853, Connecticut',
#   'P003001': 3646.0,
#   'P003002': 3508.0,
#   'P003003': 33.0,
#   'P003004': 1.0,
#   'P003005': 49.0,
#   'P003006': 4.0,
#   'P003007': 15.0,
#   'P003008': 36.0,
#   'P004002': 3530.0,
#   'P013001': 42.7,
#   'P013002': 42.5,
#   'P013003': 42.8,
#   'P015001': 1436.0,
#   'P017001': 2.54,
#   'P031001': 984.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06853'},
#  {'NAME': 'ZCTA5 06854, Connecticut',
#   'P003001': 29100.0,
#   'P003002': 15246.0,
#   'P003003': 6880.0,
#   'P003004': 145.0,
#   'P003005': 1229.0,
#   'P003006': 29.0,
#   'P003007': 4568.0,
#   'P003008': 1003.0,
#   'P004002': 18510.0,
#   'P013001': 34.1,
#   'P013002': 32.6,
#   'P013003': 35.7,
#   'P015001': 10762.0,
#   'P017001': 2.68,
#   'P031001': 6869.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06854'},
#  {'NAME': 'ZCTA5 06855, Connecticut',
#   'P003001': 7892.0,
#   'P003002': 6010.0,
#   'P003003': 763.0,
#   'P003004': 28.0,
#   'P003005': 296.0,
#   'P003006': 4.0,
#   'P003007': 579.0,
#   'P003008': 212.0,
#   'P004002': 6040.0,
#   'P013001': 38.6,
#   'P013002': 37.1,
#   'P013003': 40.2,
#   'P015001': 3251.0,
#   'P017001': 2.42,
#   'P031001': 1627.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06855'},
#  {'NAME': 'ZCTA5 06856, Connecticut',
#   'P003001': 3.0,
#   'P003002': 2.0,
#   'P003003': 1.0,
#   'P003004': 0.0,
#   'P003005': 0.0,
#   'P003006': 0.0,
#   'P003007': 0.0,
#   'P003008': 0.0,
#   'P004002': 2.0,
#   'P013001': 42.5,
#   'P013002': 45.5,
#   'P013003': 36.5,
#   'P015001': 0.0,
#   'P017001': 0.0,
#   'P031001': 0.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06856'},
#  {'NAME': 'ZCTA5 06870, Connecticut',
#   'P003001': 7316.0,
#   'P003002': 6594.0,
#   'P003003': 74.0,
#   'P003004': 15.0,
#   'P003005': 415.0,
#   'P003006': 2.0,
#   'P003007': 59.0,
#   'P003008': 157.0,
#   'P004002': 6940.0,
#   'P013001': 41.1,
#   'P013002': 40.3,
#   'P013003': 41.7,
#   'P015001': 2607.0,
#   'P017001': 2.8,
#   'P031001': 2369.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06870'},
#  {'NAME': 'ZCTA5 06877, Connecticut',
#   'P003001': 24677.0,
#   'P003002': 23171.0,
#   'P003003': 179.0,
#   'P003004': 23.0,
#   'P003005': 800.0,
#   'P003006': 12.0,
#   'P003007': 132.0,
#   'P003008': 360.0,
#   'P004002': 23724.0,
#   'P013001': 43.5,
#   'P013002': 42.6,
#   'P013003': 44.2,
#   'P015001': 8813.0,
#   'P017001': 2.77,
#   'P031001': 7359.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06877'},
#  {'NAME': 'ZCTA5 06878, Connecticut',
#   'P003001': 8043.0,
#   'P003002': 7079.0,
#   'P003003': 109.0,
#   'P003004': 8.0,
#   'P003005': 608.0,
#   'P003006': 2.0,
#   'P003007': 121.0,
#   'P003008': 116.0,
#   'P004002': 7402.0,
#   'P013001': 41.2,
#   'P013002': 39.9,
#   'P013003': 42.5,
#   'P015001': 2674.0,
#   'P017001': 2.99,
#   'P031001': 2648.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06878'},
#  {'NAME': 'ZCTA5 06880, Connecticut',
#   'P003001': 26647.0,
#   'P003002': 24649.0,
#   'P003003': 323.0,
#   'P003004': 16.0,
#   'P003005': 1061.0,
#   'P003006': 9.0,
#   'P003007': 163.0,
#   'P003008': 426.0,
#   'P004002': 25707.0,
#   'P013001': 44.7,
#   'P013002': 44.2,
#   'P013003': 45.1,
#   'P015001': 9702.0,
#   'P017001': 2.72,
#   'P031001': 7906.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06880'},
#  {'NAME': 'ZCTA5 06883, Connecticut',
#   'P003001': 10179.0,
#   'P003002': 9463.0,
#   'P003003': 131.0,
#   'P003004': 12.0,
#   'P003005': 295.0,
#   'P003006': 2.0,
#   'P003007': 82.0,
#   'P003008': 194.0,
#   'P004002': 9843.0,
#   'P013001': 43.4,
#   'P013002': 43.4,
#   'P013003': 43.5,
#   'P015001': 3379.0,
#   'P017001': 3.01,
#   'P031001': 3310.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06883'},
#  {'NAME': 'ZCTA5 06890, Connecticut',
#   'P003001': 4306.0,
#   'P003002': 4016.0,
#   'P003003': 55.0,
#   'P003004': 0.0,
#   'P003005': 156.0,
#   'P003006': 1.0,
#   'P003007': 12.0,
#   'P003008': 66.0,
#   'P004002': 4152.0,
#   'P013001': 44.7,
#   'P013002': 43.0,
#   'P013003': 45.9,
#   'P015001': 1571.0,
#   'P017001': 2.67,
#   'P031001': 1215.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06890'},
#  {'NAME': 'ZCTA5 06896, Connecticut',
#   'P003001': 9110.0,
#   'P003002': 8660.0,
#   'P003003': 63.0,
#   'P003004': 13.0,
#   'P003005': 188.0,
#   'P003006': 6.0,
#   'P003007': 35.0,
#   'P003008': 145.0,
#   'P004002': 8889.0,
#   'P013001': 46.5,
#   'P013002': 46.1,
#   'P013003': 46.8,
#   'P015001': 3455.0,
#   'P017001': 2.62,
#   'P031001': 2367.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06896'},
#  {'NAME': 'ZCTA5 06897, Connecticut',
#   'P003001': 18071.0,
#   'P003002': 16675.0,
#   'P003003': 180.0,
#   'P003004': 10.0,
#   'P003005': 827.0,
#   'P003006': 0.0,
#   'P003007': 96.0,
#   'P003008': 283.0,
#   'P004002': 17530.0,
#   'P013001': 42.9,
#   'P013002': 41.8,
#   'P013003': 43.9,
#   'P015001': 6175.0,
#   'P017001': 2.89,
#   'P031001': 5683.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06897'},
#  {'NAME': 'ZCTA5 06901, Connecticut',
#   'P003001': 6828.0,
#   'P003002': 3775.0,
#   'P003003': 1312.0,
#   'P003004': 10.0,
#   'P003005': 1123.0,
#   'P003006': 3.0,
#   'P003007': 400.0,
#   'P003008': 205.0,
#   'P004002': 5681.0,
#   'P013001': 34.1,
#   'P013002': 33.0,
#   'P013003': 35.4,
#   'P015001': 3960.0,
#   'P017001': 1.71,
#   'P031001': 735.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06901'},
#  {'NAME': 'ZCTA5 06902, Connecticut',
#   'P003001': 63406.0,
#   'P003002': 34059.0,
#   'P003003': 12463.0,
#   'P003004': 271.0,
#   'P003005': 4312.0,
#   'P003006': 68.0,
#   'P003007': 9755.0,
#   'P003008': 2478.0,
#   'P004002': 41583.0,
#   'P013001': 34.9,
#   'P013002': 33.3,
#   'P013003': 36.8,
#   'P015001': 23502.0,
#   'P017001': 2.66,
#   'P031001': 13666.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06902'},
#  {'NAME': 'ZCTA5 06903, Connecticut',
#   'P003001': 14499.0,
#   'P003002': 12868.0,
#   'P003003': 471.0,
#   'P003004': 17.0,
#   'P003005': 802.0,
#   'P003006': 1.0,
#   'P003007': 107.0,
#   'P003008': 233.0,
#   'P004002': 13782.0,
#   'P013001': 45.4,
#   'P013002': 45.0,
#   'P013003': 45.6,
#   'P015001': 5036.0,
#   'P017001': 2.84,
#   'P031001': 3700.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06903'},
#  {'NAME': 'ZCTA5 06905, Connecticut',
#   'P003001': 19649.0,
#   'P003002': 15017.0,
#   'P003003': 1260.0,
#   'P003004': 69.0,
#   'P003005': 2112.0,
#   'P003006': 7.0,
#   'P003007': 730.0,
#   'P003008': 454.0,
#   'P004002': 17219.0,
#   'P013001': 39.6,
#   'P013002': 38.0,
#   'P013003': 41.2,
#   'P015001': 7694.0,
#   'P017001': 2.53,
#   'P031001': 4381.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06905'},
#  {'NAME': 'ZCTA5 06906, Connecticut',
#   'P003001': 9088.0,
#   'P003002': 6569.0,
#   'P003003': 913.0,
#   'P003004': 15.0,
#   'P003005': 723.0,
#   'P003006': 1.0,
#   'P003007': 567.0,
#   'P003008': 300.0,
#   'P004002': 7250.0,
#   'P013001': 36.8,
#   'P013002': 35.5,
#   'P013003': 38.1,
#   'P015001': 3537.0,
#   'P017001': 2.56,
#   'P031001': 1919.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06906'},
#  {'NAME': 'ZCTA5 06907, Connecticut',
#   'P003001': 9016.0,
#   'P003002': 7216.0,
#   'P003003': 661.0,
#   'P003004': 11.0,
#   'P003005': 596.0,
#   'P003006': 6.0,
#   'P003007': 340.0,
#   'P003008': 186.0,
#   'P004002': 7788.0,
#   'P013001': 38.2,
#   'P013002': 37.0,
#   'P013003': 39.5,
#   'P015001': 3563.0,
#   'P017001': 2.53,
#   'P031001': 2032.0,
#   'state': '09',
#   'zip code tabulation area (or part)': '06907'}]
