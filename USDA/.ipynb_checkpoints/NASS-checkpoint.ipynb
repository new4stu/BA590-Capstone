# %%
# importing proper libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import sklearn
import nass

# %%
# Access USDA stats from the National Agricultural Statistics Service (NASS)
# Get row count of data

from nass import NassApi
api = NassApi('5B9610D0-2DBF-389B-BA0C-38CA734388B6')
api.param_values('source_desc')
['CENSUS', 'SURVEY']

q = api.query()
q.count()
# Out:
# 41502014

# %%
# cont of query results

q = api.query()
q.filter('commodity_desc', 'LETTUCE').filter('year', '2010')
for t in q.filter('year', in range(2010,2018): ) 
    range
#.filter('year', '2011')
#.filter('zip_5', '06608')
q.count()

#q.execute()
#[{'Sector_desc': 'CROPS', 'Group_desc', 'VEGETABLES'}]
# Out:
# 3094

# %%
results = []
for i in range(2010,2018):
    #print(i)
    q.filter('commodity_desc', 'LETTUCE').filter('year', str(i))
    y = q.execute()
    results.append(y)

# %%
results[0]
# Out:
# [{'week_ending': '',
#   'state_name': 'US TOTAL',
#   'country_code': '9000',
#   'location_desc': 'US TOTAL',
#   'begin_code': '01',
#   'zip_5': '',
#   'county_ansi': '',
#   'state_alpha': 'US',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'domain_desc': 'TOTAL',
#   'asd_desc': '',
#   'freq_desc': 'MONTHLY',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'end_code': '01',
#   'sector_desc': 'CROPS',
#   'short_desc': 'LETTUCE, HEAD - PRICE RECEIVED, PARITY, MEASURED IN $ / CWT',
#   'country_name': 'UNITED STATES',
#   'Value': '57.4',
#   'reference_period_desc': 'JAN',
#   'CV (%)': '',
#   'class_desc': 'HEAD',
#   'asd_code': '',
#   'agg_level_desc': 'NATIONAL',
#   'county_name': '',
#   'region_desc': '',
#   'watershed_desc': '',
#   'state_ansi': '',
#   'congr_district_code': '',
#   'domaincat_desc': 'NOT SPECIFIED',
#   'state_fips_code': '99',
#   'group_desc': 'VEGETABLES',
#   'watershed_code': '00000000',
#   'unit_desc': '$ / CWT',
# ...

# %%
q.execute()
#[{'Sector_desc': 'CROPS', 'Group_desc', 'VEGETABLES'}]
# Out:
# [{'week_ending': '',
#   'state_name': 'US TOTAL',
#   'country_code': '9000',
#   'location_desc': 'US TOTAL',
#   'begin_code': '01',
#   'zip_5': '',
#   'county_ansi': '',
#   'state_alpha': 'US',
#   'util_practice_desc': 'ALL UTILIZATION PRACTICES',
#   'domain_desc': 'TOTAL',
#   'asd_desc': '',
#   'freq_desc': 'MONTHLY',
#   'prodn_practice_desc': 'ALL PRODUCTION PRACTICES',
#   'end_code': '01',
#   'sector_desc': 'CROPS',
#   'short_desc': 'LETTUCE, HEAD - PRICE RECEIVED, MEASURED IN $ / CWT',
#   'country_name': 'UNITED STATES',
#   'Value': '33.8',
#   'reference_period_desc': 'JAN',
#   'CV (%)': '',
#   'class_desc': 'HEAD',
#   'asd_code': '',
#   'agg_level_desc': 'NATIONAL',
#   'county_name': '',
#   'region_desc': '',
#   'watershed_desc': '',
#   'state_ansi': '',
#   'congr_district_code': '',
#   'domaincat_desc': 'NOT SPECIFIED',
#   'state_fips_code': '99',
#   'group_desc': 'VEGETABLES',
#   'watershed_code': '00000000',
#   'unit_desc': '$ / CWT',
# ...

# %%
# 

q.filter('commodity_desc', 'CORN').filter('year', 2012)
